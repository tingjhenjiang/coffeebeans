# %%
"""
{
  "data": {
    "image": "http://localhost:8080/static/samples/sample.jpg" 
  },

  "predictions": [{
    "result": [
      {
        "id": "result1",
        "type": "rectanglelabels",        
        "from_name": "label", "to_name": "image",
        "original_width": 600, "original_height": 403,
        "image_rotation": 0,
        "value": {
          "rotation": 0,          
          "x": 4.98, "y": 12.82,
          "width": 32.52, "height": 44.91,
          "rectanglelabels": ["Airplane"]
        }
      },
      {
        "id": "result2",
        "type": "rectanglelabels",        
        "from_name": "label", "to_name": "image",
        "original_width": 600, "original_height": 403,
        "image_rotation": 0,
        "value": {
          "rotation": 0,          
          "x": 75.47, "y": 82.33,
          "width": 5.74, "height": 7.40,
          "rectanglelabels": ["Car"]
        }
      },
      {
        "id": "result3",
        "type": "choices",
        "from_name": "choice", "to_name": "image",
        "value": {
          "choices": ["Airbus"]
        }
      }
    ]
  }]
}
"""

# %%
from lxml import etree
from copy import deepcopy
from io import BytesIO
import os, glob, math
import re, sys, json, time, os, six, getpass, requests, cv2
import dask
import pandas as pd
import numpy as np
from IPython.display import display

def recursive_dict(element):
     return element.tag, \
            dict(map(recursive_dict, element)) or element.text
def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

#https://blog.paperspace.com/data-augmentation-for-object-detection-rotation-and-shearing/
def get_corners(bboxes):
    """Get corners of bounding boxes
    Parameters
    ----------
    bboxes: numpy.ndarray
        Numpy array containing bounding boxes of shape `N X 4` where N is the 
        number of bounding boxes and the bounding boxes are represented in the
        format `x1 y1 x2 y2`
    returns
    -------
    numpy.ndarray
        Numpy array of shape `N x 8` containing N bounding boxes each described by their 
        corner co-ordinates `x1 y1 x2 y2 x3 y3 x4 y4`  
    """
    width = (bboxes[:,2] - bboxes[:,0]).reshape(-1,1)
    height = (bboxes[:,3] - bboxes[:,1]).reshape(-1,1)    
    x1 = bboxes[:,0].reshape(-1,1)
    y1 = bboxes[:,1].reshape(-1,1)
    x2 = x1 + width
    y2 = y1 
    x3 = x1
    y3 = y1 + height
    x4 = bboxes[:,2].reshape(-1,1)
    y4 = bboxes[:,3].reshape(-1,1)
    corners = np.hstack((x1,y1,x2,y2,x3,y3,x4,y4))
    return corners

def rotate_box(corners, angle, cx, cy, h, w):
    """Rotate the bounding box.
    Parameters
    ----------
    corners : numpy.ndarray
        Numpy array of shape `N x 8` containing N bounding boxes each described by their 
        corner co-ordinates `x1 y1 x2 y2 x3 y3 x4 y4`
    angle : float
        angle by which the image is to be rotated
    cx : int
        x coordinate of the center of image (about which the box will be rotated)
    cy : int
        y coordinate of the center of image (about which the box will be rotated)
    h : int 
        height of the image
    w : int 
        width of the image
    Returns
    -------
    numpy.ndarray
        Numpy array of shape `N x 8` containing N rotated bounding boxes each described by their 
        corner co-ordinates `x1 y1 x2 y2 x3 y3 x4 y4`
    """

    corners = corners.reshape(-1,2)
    corners = np.hstack((corners, np.ones((corners.shape[0],1), dtype = type(corners[0][0]))))
    M = cv2.getRotationMatrix2D((cx, cy), angle, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))
    # adjust the rotation matrix to take into account translation
    M[0, 2] += (nW / 2) - cx
    M[1, 2] += (nH / 2) - cy
    # Prepare the vector to be transformed
    calculated = np.dot(M,corners.T).T
    calculated = calculated.reshape(-1,8)
    return calculated, nW, nH

def get_enclosing_box(corners):
    """Get an enclosing box for ratated corners of a bounding box
    Parameters
    ----------
    corners : numpy.ndarray
        Numpy array of shape `N x 8` containing N bounding boxes each described by their 
        corner co-ordinates `x1 y1 x2 y2 x3 y3 x4 y4`  
    Returns 
    -------
    numpy.ndarray
        Numpy array containing enclosing bounding boxes of shape `N X 4` where N is the 
        number of bounding boxes and the bounding boxes are represented in the
        format `x1 y1 x2 y2`
    """
    x_ = corners[:,[0,2,4,6]]
    y_ = corners[:,[1,3,5,7]]
    xmin = np.min(x_,1).reshape(-1,1)
    ymin = np.min(y_,1).reshape(-1,1)
    xmax = np.max(x_,1).reshape(-1,1)
    ymax = np.max(y_,1).reshape(-1,1)
    final = np.hstack((xmin, ymin, xmax, ymax,corners[:,8:]))
    return final


def rotate_get_new_cord(x, y=0, imgw=100, imgh=100, degree=0):
    """
    X=xcos(θ)+ysin(θ)
    Y=−xsin(θ)+ycos(θ)
    """
    largerOneOfWidthHeight = max([x,y])
    originX = imgw//2
    originY = imgh//2
    yNormalCoordinateSystem = imgh-y #Y軸轉換為一般座標系算法
    xOriginSetToImageCenter = x-originX #設定原點在圖中間
    yOriginSetToImageCenter = yNormalCoordinateSystem-originY
    radian = math.pi*(degree/180)
    xRotated = xOriginSetToImageCenter * math.cos(radian) - yOriginSetToImageCenter * math.sin(radian)
    yRotated = xOriginSetToImageCenter * math.sin(radian) * -1 + yOriginSetToImageCenter * math.cos(radian) #轉軸公式
    newWidth = imgw * math.cos(radian) + imgh * math.sin(radian)
    newHeight = imgw * math.sin(radian) + imgh * math.cos(radian)
    xOriginSetAwayFromImageCenter = xRotated+originX #unset原點在圖中間
    yOriginSetAwayFromImageCenter = yRotated+originY
    yComputerImageCoordinateSystem = imgh-yOriginSetAwayFromImageCenter #y軸轉換為電腦圖片算法
    xScaled = xOriginSetAwayFromImageCenter #/newWidth*imgw
    yScaled = yComputerImageCoordinateSystem #/newHeight*imgh
    return round(xScaled), round(yScaled), newWidth, newHeight

testbboxes = np.array([[0,0,100,100]]) #x1 y1 x2 y2
testwidth = 400
testheight = 100
#testTransformedBox = rotate_box()

if True:
    corners, newWidth, newHeight = rotate_box(get_corners(testbboxes), 90, testwidth//2, testheight//2, testheight, testwidth)
    display(np.round(corners), newWidth, newHeight) #x1 y1 x2 y2 x3 y3 x4 y4
    testenclosingbox = get_enclosing_box(corners) #x1 y1 x2 y2
    #display(testenclosingbox)
    display(np.round(testenclosingbox))
    #display(cv2.getRotationMatrix2D((cX, cY), -angle, 1.0))
#returns x1 y1 x2 y2 x3 y3 x4 y4
#display(rotate_get_new_cord(4000,0,testwidth,testheight,90))
#display(cv2.getRotationMatrix2D((testwidth//2, testheight//2), -90, 1.0).shape)
#(0,0) -> (100,0) -> (100,100) -> (0,100)
# Out:
# array([[ -0., 400.,  -0., 300., 100., 400., 100., 300.]])
# 100
# 400
# array([[ -0., 300., 100., 400.]])

# %%
rootpath = 'F:\\coffee-beans\\'
newWebPathBase = ['/data/local-files/?d=coffee-beans/', 'http://192.168.10.200/coffeebeans/'][1]
replaceSourcePath = 'F:\\T大使咖啡豆圖片\\'
resultDict = []
xmlFilePaths = {os.path.basename(f):f for f in glob.iglob(rootpath+'**/*.xml', recursive=True)} #+ 'labels\\IChang_bad'
#xmlBaseFileNames = [os.path.basename(f) for i,f in enumerate(xmlFilePaths)]
jpgFilePaths = [f for f in glob.iglob(rootpath+ '**/*.jpg', recursive=True)] # if os.path.basename(f).replace('.jpg','.xml') not in xmlFilePaths.keys()
print(len(jpgFilePaths))
print(len(xmlFilePaths))
#print(jpgFilePaths)
# Out:
# 652
# 104

# %%
for jpgFilePath_i,jpgFilePath in enumerate(jpgFilePaths):
    print(jpgFilePath_i, jpgFilePath)
    singleImageDict = {}
    testMatchingXMLFileName = os.path.basename(jpgFilePath).replace('.jpg','.xml')
    predictionDictBase = {
        "type": "rectanglelabels",        
        "from_name": "label", "to_name": "image",
        "image_rotation": 0,
    }
    if testMatchingXMLFileName in xmlFilePaths.keys():
        xmlFilePath = xmlFilePaths[testMatchingXMLFileName]
        f = open(xmlFilePath, 'r', encoding='utf-8')
        xmlContent = f.read()
        f.close()
        tree = etree.fromstring(xmlContent)
        imageFilePath = list(tree.iter("path"))[0].text
        originalSize = recursive_dict(list(tree.iter("size"))[0])[1]
        sourceSizeDict = {"original_width": int(originalSize['width']), "original_height": int(originalSize['height'])}
        #newImageFilePath = imageFilePath.replace(rootpath,newWebPathBase).replace(replaceSourcePath,newWebPathBase).replace('\\','/')
        newImageFilePath = jpgFilePath.replace(rootpath,newWebPathBase).replace(replaceSourcePath,newWebPathBase).replace('\\','/')
        singleImageDict['data'] = {'image': newImageFilePath}
        needToRotate = True if sourceSizeDict['original_width']!=3024 else False
        originalSizeDict = {"original_width": 3024, "original_height": 4032} if needToRotate==True else sourceSizeDict
        predictionDictBase = {**predictionDictBase, **originalSizeDict}
        annotatedObjs = []
        #print(predictionDictBase)
        angle = -90
        for keyi, element in enumerate(tree.iter("object")):
            elementDict = recursive_dict(element)
            #print("keyi is {} and needToRotate is {}".format(keyi, needToRotate))
            if needToRotate==True:
                testbboxes = np.array([[int(elementDict[1]['bndbox']['xmin']),int(elementDict[1]['bndbox']['ymin']),int(elementDict[1]['bndbox']['xmax']),int(elementDict[1]['bndbox']['ymax'])]]) #x1 y1 x2 y2
                testwidth = sourceSizeDict['original_width']
                testheight = sourceSizeDict['original_height']
                corners, newImageWidth, newImageHeight = rotate_box(get_corners(testbboxes), angle, testwidth//2, testheight//2, testheight, testwidth)
                #display(np.round(corners)) #x1 y1 x2 y2 x3 y3 x4 y4
                testenclosingbox = np.round(get_enclosing_box(corners))[0,:] #x1 y1 x2 y2
                newXminAxis = testenclosingbox[0]/newImageWidth*100
                newYminAxis = testenclosingbox[1]/newImageHeight*100
                newXmaxAxis = testenclosingbox[2]/newImageWidth*100
                newYmaxAxis = testenclosingbox[3]/newImageHeight*100
                newBBoxWidth = abs(newXmaxAxis-newXminAxis)
                newBBoxHeight = abs(newYmaxAxis-newYminAxis)
                #display("newXminAxis is {}; newYminAxis is{}; newXmaxAxis is {}; newYmaxAxis is {}".format(newXminAxis,newYminAxis,newXmaxAxis,newYmaxAxis))
            else:
                newXminAxis = int(elementDict[1]['bndbox']['xmin'])/int(originalSize['width'])*100
                newYminAxis = int(elementDict[1]['bndbox']['ymin'])/int(originalSize['height'])*100
                newBBoxWidth = (int(elementDict[1]['bndbox']['xmax']) - int(elementDict[1]['bndbox']['xmin']))/int(originalSize['width'])*100
                newBBoxHeight = ( int(elementDict[1]['bndbox']['ymax']) - int(elementDict[1]['bndbox']['ymin']))/int(originalSize['height'])*100
            """
                {
                "id": "result2",
                "type": "rectanglelabels",        
                "from_name": "label", "to_name": "image",
                "original_width": 600, "original_height": 403,
                "image_rotation": 0,
                "value": {
                    "rotation": 0,          
                    "x": 75.47, "y": 82.33,
                    "width": 5.74, "height": 7.40,
                    "rectanglelabels": ["Car"]
                    }
                }
            """
            coffeeObjDict = (merge_two_dicts(
                predictionDictBase,
                {
                    'id': 'result'+str(keyi+1),
                    'value': {
                    "rotation": 0,
                    'x':newXminAxis,
                    'y':newYminAxis,
                    'width':newBBoxWidth,
                    'height':newBBoxHeight,
                    "rectanglelabels": [elementDict[1]['name']]
                }}
            ))
            annotatedObjs.append(coffeeObjDict)
            #display(elementDict)
            #break
        annotationAuthor = ['s110109@shsh.tw','Chen','YiChang',2] if re.search('IChang_bad',xmlFilePath)!=None else ['tingjhenjiang@gmail.com','Jiang','TingJhen',1]
        annotationAuthorDict = {
            "id":annotationAuthor[3],
            "email":annotationAuthor[0],
            "first_name":annotationAuthor[2],
            "last_name":annotationAuthor[1]
        }
        singleImageDict['annotations'] = [{'result':annotatedObjs}]
        singleImageDict['completed_by'] = annotationAuthorDict
    else:
        #im = cv2.imread(jpgFilePath)
        #originalSizeDict = {"original_width": im.shape[1], "original_height": im.shape[0]}
        newImageFilePath = jpgFilePath.replace(rootpath,newWebPathBase).replace(replaceSourcePath,newWebPathBase).replace('\\','/')
        singleImageDict['data'] = {'image': newImageFilePath}
        annotationAuthor = [None]
        #predictionDictBase = {**predictionDictBase, **originalSizeDict}
    singleImageDict['id'] = jpgFilePath_i+1
    if (annotationAuthor[0] in [None]): #'tingjhenjiang@gmail.com' 's110109@shsh.tw'
        #display(singleImageDict)
        #sys.exit()
        resultDict.append(singleImageDict)
        #print(annotationAuthor)
        #break
    else:
        next


    #break
    #print(os.path.basename(jpgFilePath).replace('.jpg','.xml'))
#print(list(xmlFilePaths.keys()))
#print(list(xmlFilePaths.keys()))
# Out:
# \coffee-beans\images\good\20210420_155246.jpg
# 220 F:\coffee-beans\images\good\20210420_155258.jpg
# 221 F:\coffee-beans\images\good\20210420_155304.jpg
# 222 F:\coffee-beans\images\good\20210420_155310.jpg
# 223 F:\coffee-beans\images\good\20210420_155317.jpg
# 224 F:\coffee-beans\images\good\20210420_155323.jpg
# 225 F:\coffee-beans\images\good\20210420_155328.jpg
# 226 F:\coffee-beans\images\good\20210420_155336.jpg
# 227 F:\coffee-beans\images\good\20210420_155343.jpg
# 228 F:\coffee-beans\images\good\20210420_155352.jpg
# 229 F:\coffee-beans\images\good\IMAG0488.jpg
# 230 F:\coffee-beans\images\good\IMAG0489.jpg
# 231 F:\coffee-beans\images\good\IMAG0490.jpg
# 232 F:\coffee-beans\images\good\IMAG0491.jpg
# 233 F:\coffee-beans\images\good\IMAG0492.jpg
# 234 F:\coffee-beans\images\good\IMAG0493.jpg
# 235 F:\coffee-beans\images\good\IMAG0494.jpg
# 236 F:\coffee-beans\images\good\IMAG0495.jpg
# 237 F:\coffee-beans\images\good\IMAG0496.jpg
# 238 F:\coffee-beans\images\good\IMAG0497.jpg
# 239 F:\coffee-beans\images\good\IMAG0498.jpg
# 240 F:\coffee-beans\images\good\IMAG0499.jpg
# 241 F:\coffee-beans\images\good\IMAG0500.jpg
# 242 F:\coffee-beans\images\good\IMAG0501.jpg
# 243 F:\coffee-beans\images\good\IMAG0502.jpg
# 244 F:\coffee-beans\images\good\IMAG0503.jpg
# 245 F:\coffee-beans\images\good\IMAG0504.jpg
# 246 F:\coffee-beans\images\good\IMAG0505.jpg
# 247 F:\coffee-beans\images\good\IMAG0506.jpg
# 248 F:\coffee-beans\images\good\IMAG0507.jpg
# 249 F:\coffee-beans\images\good\IMAG0508.jpg
# 250 F:\coffee-beans\images\good\IMAG0509.jpg
# 251 F:\coffee-beans\images\good\IMAG0510.jpg
# 252 F:\coffee-beans\images\good\IMAG0511.jpg
# 253 F:\coffee-beans\images\good\IMAG0512.jpg
# 254 F:\coffee-beans\images\good\IMAG0514.jpg
# 255 F:\coffee-beans\images\good\IMAG0515.jpg
# 256 F:\coffee-beans\images\good\IMAG0523.jpg
# 257 F:\coffee-beans\images\good\IMAG0531.jpg
# 258 F:\coffee-beans\images\good\IMAG0533.jpg
# 259 F:\coffee-beans\images\good\IMAG0534.jpg
# 260 F:\coffee-beans\images\good\IMAG0535.jpg
# 261 F:\coffee-beans\images\good\IMAG0536.jpg
# 262 F:\coffee-beans\images\good\IMAG0538.jpg
# 263 F:\coffee-beans\images\good\IMAG0543.jpg
# 264 F:\coffee-beans\images\good\IMAG0544.jpg
# 265 F:\coffee-beans\images\good\IMAG0545.jpg
# 266 F:\coffee-beans\images\good\IMAG0546.jpg
# 267 F:\coffee-beans\images\good\IMAG0547.jpg
# 268 F:\coffee-beans\images\good\IMAG0548.jpg
# 269 F:\coffee-beans\images\good\IMAG0549.jpg
# 270 F:\coffee-beans\images\good\IMAG0550.jpg
# 271 F:\coffee-beans\images\good\IMAG0551.jpg
# 272 F:\coffee-beans\images\good\IMAG0552.jpg
# 273 F:\coffee-beans\images\good\IMAG0553.jpg
# 274 F:\coffee-beans\images\good\IMAG0554.jpg
# 275 F:\coffee-beans\images\good\IMAG0559.jpg
# 276 F:\coffee-beans\images\good\IMAG0560.jpg
# 277 F:\coffee-beans\images\good\IMAG0561.jpg
# 278 F:\coffee-beans\images\good\IMAG0562.jpg
# 279 F:\coffee-beans\images\good\IMAG0563.jpg
# 280 F:\coffee-beans\images\good\IMAG0564.jpg
# 281 F:\coffee-beans\images\good\IMAG0565.jpg
# 282 F:\coffee-beans\images\good\IMAG0566.jpg
# 283 F:\coffee-beans\images\good\IMAG0567.jpg
# 284 F:\coffee-beans\images\good\IMAG0568.jpg
# 285 F:\coffee-beans\images\good\IMAG0569.jpg
# 286 F:\coffee-beans\images\good\IMAG0570.jpg
# 287 F:\coffee-beans\images\good\IMAG0571.jpg
# 288 F:\coffee-beans\images\good\IMAG0572.jpg
# 289 F:\coffee-beans\images\good\IMAG0573.jpg
# 290 F:\coffee-beans\images\good\IMAG0574.jpg
# 291 F:\coffee-beans\images\good\IMAG0575.jpg
# 292 F:\coffee-beans\images\good\IMAG0576.jpg
# 293 F:\coffee-beans\images\good\IMAG0577.jpg
# 294 F:\coffee-beans\images\good\IMAG0578.jpg
# 295 F:\coffee-beans\images\good\IMAG0579.jpg
# 296 F:\coffee-beans\images\good\IMAG0580.jpg
# 297 F:\coffee-beans\images\good\IMAG0581.jpg
# 298 F:\coffee-beans\images\good\IMAG0582.jpg
# 299 F:\coffee-beans\images\good\IMAG0583.jpg
# 300 F:\coffee-beans\images\good\IMAG0584.jpg
# 301 F:\coffee-beans\images\good\IMAG0585.jpg
# 302 F:\coffee-beans\images\good\IMAG0586.jpg
# 303 F:\coffee-beans\images\good\IMAG0587.jpg
# 304 F:\coffee-beans\images\good\IMAG0588.jpg
# 305 F:\coffee-beans\images\good\IMAG0589.jpg
# 306 F:\coffee-beans\images\good\IMAG0590.jpg
# 307 F:\coffee-beans\images\good\IMAG0591.jpg
# 308 F:\coffee-beans\images\good\IMAG0592.jpg
# 309 F:\coffee-beans\images\good\IMAG0593.jpg
# 310 F:\coffee-beans\images\good\IMAG0594.jpg
# 311 F:\coffee-beans\images\good\IMAG0595.jpg
# 312 F:\coffee-beans\images\good\IMAG0597.jpg
# 313 F:\coffee-beans\images\good\IMAG0598.jpg
# 314 F:\coffee-beans\images\good\IMAG0599.jpg
# 315 F:\coffee-beans\images\good\IMAG0600.jpg
# 316 F:\coffee-beans\images\good\IMAG0601.jpg
# 317 F:\coffee-beans\images\good\IMAG0602.jpg
# 318 F:\coffee-beans\images\good\IMAG0603.jpg
# 319 F:\coffee-beans\images\good\IMAG0797.jpg
# 320 F:\coffee-beans\images\good\IMAG0798.jpg
# 321 F:\coffee-beans\images\good\IMAG0799.jpg
# 322 F:\coffee-beans\images\good\IMAG0800.jpg
# 323 F:\coffee-beans\images\good\IMAG0801.jpg
# 324 F:\coffee-beans\images\good\IMAG0802.jpg
# 325 F:\coffee-beans\images\good\IMAG0803.jpg
# 326 F:\coffee-beans\images\good\IMAG0804.jpg
# 327 F:\coffee-beans\images\good\IMAG0805.jpg
# 328 F:\coffee-beans\images\good\IMAG0806.jpg
# 329 F:\coffee-beans\images\good\IMAG0807.jpg
# 330 F:\coffee-beans\images\good\IMAG0808.jpg
# 331 F:\coffee-beans\images\good\IMAG0809.jpg
# 332 F:\coffee-beans\images\good\IMAG0810.jpg
# 333 F:\coffee-beans\images\good\IMAG0811.jpg
# 334 F:\coffee-beans\images\good\IMAG0812.jpg
# 335 F:\coffee-beans\images\good\IMAG0813.jpg
# 336 F:\coffee-beans\images\good\IMAG0814.jpg
# 337 F:\coffee-beans\images\good\IMAG0815.jpg
# 338 F:\coffee-beans\images\good\IMAG0816.jpg
# 339 F:\coffee-beans\images\good\IMAG0817.jpg
# 340 F:\coffee-beans\images\good\IMAG0818.jpg
# 341 F:\coffee-beans\images\good\IMAG0819.jpg
# 342 F:\coffee-beans\images\good\IMAG0820.jpg
# 343 F:\coffee-beans\images\good\IMAG0821.jpg
# 344 F:\coffee-beans\images\good\IMAG0822.jpg
# 345 F:\coffee-beans\images\good\IMAG0823.jpg
# 346 F:\coffee-beans\images\good\IMAG0824.jpg
# 347 F:\coffee-beans\images\good\IMAG0825.jpg
# 348 F:\coffee-beans\images\good\IMAG0826.jpg
# 349 F:\coffee-beans\images\good\IMAG0827.jpg
# 350 F:\coffee-beans\images\good\IMAG0828.jpg
# 351 F:\coffee-beans\images\good\IMAG0829.jpg
# 352 F:\coffee-beans\images\good\IMAG0830.jpg
# 353 F:\coffee-beans\images\good\IMAG0831.jpg
# 354 F:\coffee-beans\images\good\IMAG0832.jpg
# 355 F:\coffee-beans\images\good\IMAG0833.jpg
# 356 F:\coffee-beans\images\good\IMAG0834.jpg
# 357 F:\coffee-beans\images\good\IMAG0835.jpg
# 358 F:\coffee-beans\images\good\IMAG0836.jpg
# 359 F:\coffee-beans\images\good\IMAG0837.jpg
# 360 F:\coffee-beans\images\good\IMAG0838.jpg
# 361 F:\coffee-beans\images\good\IMAG0839.jpg
# 362 F:\coffee-beans\images\good\IMAG0840.jpg
# 363 F:\coffee-beans\images\good\IMAG0841.jpg
# 364 F:\coffee-beans\images\good\IMAG0842.jpg
# 365 F:\coffee-beans\images\good\IMAG0843.jpg
# 366 F:\coffee-beans\images\good\IMAG0844.jpg
# 367 F:\coffee-beans\images\good\IMAG0845.jpg
# 368 F:\coffee-beans\images\good\IMAG0846.jpg
# 369 F:\coffee-beans\images\good\IMAG0847.jpg
# 370 F:\coffee-beans\images\good\IMAG0848.jpg
# 371 F:\coffee-beans\images\good\IMAG0849.jpg
# 372 F:\coffee-beans\images\good\IMAG0850.jpg
# 373 F:\coffee-beans\images\good\IMAG0851.jpg
# 374 F:\coffee-beans\images\good\IMAG0852.jpg
# 375 F:\coffee-beans\images\good\IMAG0853.jpg
# 376 F:\coffee-beans\images\good\IMAG0854.jpg
# 377 F:\coffee-beans\images\good\IMAG0855.jpg
# 378 F:\coffee-beans\images\good\IMAG0856.jpg
# 379 F:\coffee-beans\images\good\IMAG0857.jpg
# 380 F:\coffee-beans\images\good\IMAG0858.jpg
# 381 F:\coffee-beans\images\good\IMAG0859.jpg
# 382 F:\coffee-beans\images\good\IMAG0860.jpg
# 383 F:\coffee-beans\images\good\IMAG0861.jpg
# 384 F:\coffee-beans\images\good\IMAG0862.jpg
# 385 F:\coffee-beans\images\good\IMAG0863.jpg
# 386 F:\coffee-beans\images\good\IMAG0864.jpg
# 387 F:\coffee-beans\images\good\IMAG0865.jpg
# 388 F:\coffee-beans\images\good\IMAG0866.jpg
# 389 F:\coffee-beans\images\good\IMAG0867.jpg
# 390 F:\coffee-beans\images\good\IMAG0868.jpg
# 391 F:\coffee-beans\images\good\IMAG0869.jpg
# 392 F:\coffee-beans\images\good\IMAG0870.jpg
# 393 F:\coffee-beans\images\good\IMAG0871.jpg
# 394 F:\coffee-beans\images\good\IMAG0872.jpg
# 395 F:\coffee-beans\images\good\IMAG0873.jpg
# 396 F:\coffee-beans\images\good\IMAG0874.jpg
# 397 F:\coffee-beans\images\good\IMAG0875.jpg
# 398 F:\coffee-beans\images\good\IMAG0876.jpg
# 399 F:\coffee-beans\images\good\IMAG0877.jpg
# 400 F:\coffee-beans\images\good\IMAG0878.jpg
# 401 F:\coffee-beans\images\good\IMAG0879.jpg
# 402 F:\coffee-beans\images\good\IMAG0880.jpg
# 403 F:\coffee-beans\images\good\IMAG0881.jpg
# 404 F:\coffee-beans\images\good\IMAG0882.jpg
# 405 F:\coffee-beans\images\good\IMAG0883.jpg
# 406 F:\coffee-beans\images\good\IMAG0884.jpg
# 407 F:\coffee-beans\images\good\IMAG0885.jpg
# 408 F:\coffee-beans\images\good\IMAG0886.jpg
# 409 F:\coffee-beans\images\good\IMAG0887.jpg
# 410 F:\coffee-beans\images\good\IMAG0888.jpg
# 411 F:\coffee-beans\images\good\IMAG0889.jpg
# 412 F:\coffee-beans\images\good\IMAG0890.jpg
# 413 F:\coffee-beans\images\good\IMAG0891.jpg
# 414 F:\coffee-beans\images\good\IMAG0892.jpg
# 415 F:\coffee-beans\images\good\IMAG0893.jpg
# 416 F:\coffee-beans\images\good\IMAG0894.jpg
# 417 F:\coffee-beans\images\good\IMAG0895.jpg
# 418 F:\coffee-beans\images\good\IMAG0896.jpg
# 419 F:\coffee-beans\images\good\IMAG0897.jpg
# 420 F:\coffee-beans\images\good\IMAG0898.jpg
# 421 F:\coffee-beans\images\good\IMAG0899.jpg
# 422 F:\coffee-beans\images\good\IMAG0900.jpg
# 423 F:\coffee-beans\images\good\IMAG0901.jpg
# 424 F:\coffee-beans\images\good\IMAG0902.jpg
# 425 F:\coffee-beans\images\good\IMAG0903.jpg
# 426 F:\coffee-beans\images\good\IMAG0904.jpg
# 427 F:\coffee-beans\images\good\IMAG0905.jpg
# 428 F:\coffee-beans\images\good\IMAG0906.jpg
# 429 F:\coffee-beans\images\good\IMAG0907.jpg
# 430 F:\coffee-beans\images\good\IMAG0908.jpg
# 431 F:\coffee-beans\images\good\IMAG0909.jpg
# 432 F:\coffee-beans\images\good\IMAG0910.jpg
# 433 F:\coffee-beans\images\good\IMAG0911.jpg
# 434 F:\coffee-beans\images\good\IMAG0912.jpg
# 435 F:\coffee-beans\images\good\IMAG0913.jpg
# 436 F:\coffee-beans\images\good\IMAG0914.jpg
# 437 F:\coffee-beans\images\good\IMAG0915.jpg
# 438 F:\coffee-beans\images\good\IMAG0916.jpg
# 439 F:\coffee-beans\images\good\IMAG0917.jpg
# 440 F:\coffee-beans\images\good\IMAG0918.jpg
# 441 F:\coffee-beans\images\good\IMAG0919.jpg
# 442 F:\coffee-beans\images\good\IMAG0920.jpg
# 443 F:\coffee-beans\images\good\IMAG0921.jpg
# 444 F:\coffee-beans\images\good\IMAG0922.jpg
# 445 F:\coffee-beans\images\good\IMAG0923.jpg
# 446 F:\coffee-beans\images\good\IMAG0924.jpg
# 447 F:\coffee-beans\images\good\IMAG0925.jpg
# 448 F:\coffee-beans\images\good\IMAG0926.jpg
# 449 F:\coffee-beans\images\good\IMAG0927.jpg
# 450 F:\coffee-beans\images\good\IMAG0928.jpg
# 451 F:\coffee-beans\images\good\IMAG0929.jpg
# 452 F:\coffee-beans\images\good\IMAG0930.jpg
# 453 F:\coffee-beans\images\good\IMAG0931.jpg
# 454 F:\coffee-beans\images\good\IMAG0932.jpg
# 455 F:\coffee-beans\images\good\IMAG0933.jpg
# 456 F:\coffee-beans\images\good\IMAG0934.jpg
# 457 F:\coffee-beans\images\good\IMAG0935.jpg
# 458 F:\coffee-beans\images\good\IMAG0936.jpg
# 459 F:\coffee-beans\images\good\IMAG0938.jpg
# 460 F:\coffee-beans\images\good\IMAG0939.jpg
# 461 F:\coffee-beans\images\good\IMAG0940.jpg
# 462 F:\coffee-beans\images\good\IMAG0941.jpg
# 463 F:\coffee-beans\images\good\IMAG0942.jpg
# 464 F:\coffee-beans\images\good\IMG_6402.JPG
# 465 F:\coffee-beans\images\good\IMG_6403.JPG
# 466 F:\coffee-beans\images\good\IMG_6404.JPG
# 467 F:\coffee-beans\images\good\IMG_6405.JPG
# 468 F:\coffee-beans\images\good\IMG_6406.JPG
# 469 F:\coffee-beans\images\good\IMG_6407.JPG
# 470 F:\coffee-beans\images\good\IMG_6408.JPG
# 471 F:\coffee-beans\images\good\IMG_6409.JPG
# 472 F:\coffee-beans\images\good\IMG_6410.JPG
# 473 F:\coffee-beans\images\good\IMG_6411.JPG
# 474 F:\coffee-beans\images\mixed\20210420_155504.jpg
# 475 F:\coffee-beans\images\mixed\20210420_155513.jpg
# 476 F:\coffee-beans\images\mixed\20210420_155528.jpg
# 477 F:\coffee-beans\images\mixed\20210420_155540.jpg
# 478 F:\coffee-beans\images\mixed\20210420_155556.jpg
# 479 F:\coffee-beans\images\mixed\20210420_155607.jpg
# 480 F:\coffee-beans\images\mixed\20210420_155613.jpg
# 481 F:\coffee-beans\images\mixed\20210420_155618.jpg
# 482 F:\coffee-beans\images\mixed\20210420_155638.jpg
# 483 F:\coffee-beans\images\mixed\20210420_155644.jpg
# 484 F:\coffee-beans\images\mixed\20210420_155649.jpg
# 485 F:\coffee-beans\images\mixed\20210420_155655.jpg
# 486 F:\coffee-beans\images\mixed\20210420_155700.jpg
# 487 F:\coffee-beans\images\mixed\20210420_155820.jpg
# 488 F:\coffee-beans\images\mixed\20210420_155828.jpg
# 489 F:\coffee-beans\images\mixed\20210420_155836.jpg
# 490 F:\coffee-beans\images\mixed\20210420_155843.jpg
# 491 F:\coffee-beans\images\mixed\20210420_155848.jpg
# 492 F:\coffee-beans\images\mixed\20210420_155854.jpg
# 493 F:\coffee-beans\images\mixed\20210420_155859.jpg
# 494 F:\coffee-beans\images\mixed\20210420_155916.jpg
# 495 F:\coffee-beans\images\mixed\20210420_155925.jpg
# 496 F:\coffee-beans\images\mixed\20210420_155935.jpg
# 497 F:\coffee-beans\images\mixed\20210420_155939.jpg
# 498 F:\coffee-beans\images\mixed\20210420_160049.jpg
# 499 F:\coffee-beans\images\mixed\20210420_160056.jpg
# 500 F:\coffee-beans\images\mixed\20210420_160102.jpg
# 501 F:\coffee-beans\images\mixed\20210420_160109.jpg
# 502 F:\coffee-beans\images\mixed\20210420_160115.jpg
# 503 F:\coffee-beans\images\mixed\20210420_160120.jpg
# 504 F:\coffee-beans\images\mixed\20210420_160135.jpg
# 505 F:\coffee-beans\images\mixed\20210420_160143.jpg
# 506 F:\coffee-beans\images\mixed\20210420_160149.jpg
# 507 F:\coffee-beans\images\mixed\20210420_160157.jpg
# 508 F:\coffee-beans\images\mixed\20210420_160208.jpg
# 509 F:\coffee-beans\images\mixed\20210420_160214.jpg
# 510 F:\coffee-beans\images\mixed\20210420_160221.jpg
# 511 F:\coffee-beans\images\mixed\20210420_160227.jpg
# 512 F:\coffee-beans\images\mixed\20210420_160235.jpg
# 513 F:\coffee-beans\images\mixed\IMAG0943.jpg
# 514 F:\coffee-beans\images\mixed\IMAG0944.jpg
# 515 F:\coffee-beans\images\mixed\IMAG0945.jpg
# 516 F:\coffee-beans\images\mixed\IMAG0946.jpg
# 517 F:\coffee-beans\images\mixed\IMAG0947.jpg
# 518 F:\coffee-beans\images\mixed\IMAG0948.jpg
# 519 F:\coffee-beans\images\mixed\IMAG0949.jpg
# 520 F:\coffee-beans\images\mixed\IMAG0950.jpg
# 521 F:\coffee-beans\images\mixed\IMAG0951.jpg
# 522 F:\coffee-beans\images\mixed\IMAG0952.jpg
# 523 F:\coffee-beans\images\mixed\IMAG0953.jpg
# 524 F:\coffee-beans\images\mixed\IMAG0954.jpg
# 525 F:\coffee-beans\images\mixed\IMAG0955.jpg
# 526 F:\coffee-beans\images\mixed\IMAG0956.jpg
# 527 F:\coffee-beans\images\mixed\IMAG0957.jpg
# 528 F:\coffee-beans\images\mixed\IMAG0958.jpg
# 529 F:\coffee-beans\images\mixed\IMAG0959.jpg
# 530 F:\coffee-beans\images\mixed\IMAG0960.jpg
# 531 F:\coffee-beans\images\mixed\IMAG0961.jpg
# 532 F:\coffee-beans\images\mixed\IMAG0962.jpg
# 533 F:\coffee-beans\images\mixed\IMAG0963.jpg
# 534 F:\coffee-beans\images\mixed\IMAG0964.jpg
# 535 F:\coffee-beans\images\mixed\IMAG0965.jpg
# 536 F:\coffee-beans\images\mixed\IMAG0966.jpg
# 537 F:\coffee-beans\images\mixed\IMAG0967.jpg
# 538 F:\coffee-beans\images\mixed\IMAG0968.jpg
# 539 F:\coffee-beans\images\mixed\IMAG0969.jpg
# 540 F:\coffee-beans\images\mixed\IMAG0970.jpg
# 541 F:\coffee-beans\images\mixed\IMAG0971.jpg
# 542 F:\coffee-beans\images\mixed\IMAG0972.jpg
# 543 F:\coffee-beans\images\mixed\IMAG0973.jpg
# 544 F:\coffee-beans\images\mixed\IMAG0974.jpg
# 545 F:\coffee-beans\images\mixed\IMAG0975.jpg
# 546 F:\coffee-beans\images\mixed\IMAG0976.jpg
# 547 F:\coffee-beans\images\mixed\IMAG0977.jpg
# 548 F:\coffee-beans\images\mixed\IMAG0978.jpg
# 549 F:\coffee-beans\images\mixed\IMAG0980.jpg
# 550 F:\coffee-beans\images\mixed\IMAG0981.jpg
# 551 F:\coffee-beans\images\mixed\IMAG0982.jpg
# 552 F:\coffee-beans\images\mixed\IMAG0983.jpg
# 553 F:\coffee-beans\images\mixed\IMAG0984.jpg
# 554 F:\coffee-beans\images\mixed\IMAG0985.jpg
# 555 F:\coffee-beans\images\mixed\IMAG0986.jpg
# 556 F:\coffee-beans\images\mixed\IMAG0987.jpg
# 557 F:\coffee-beans\images\mixed\IMAG0988.jpg
# 558 F:\coffee-beans\images\mixed\IMAG0989.jpg
# 559 F:\coffee-beans\images\mixed\IMAG0990.jpg
# 560 F:\coffee-beans\images\mixed\IMAG0991.jpg
# 561 F:\coffee-beans\images\mixed\IMAG0992.jpg
# 562 F:\coffee-beans\images\mixed\IMAG0993.jpg
# 563 F:\coffee-beans\images\mixed\IMAG0994.jpg
# 564 F:\coffee-beans\images\mixed\IMAG0995.jpg
# 565 F:\coffee-beans\images\mixed\IMAG0996.jpg
# 566 F:\coffee-beans\images\mixed\IMAG0997.jpg
# 567 F:\coffee-beans\images\mixed\IMAG0998.jpg
# 568 F:\coffee-beans\images\mixed\IMAG0999.jpg
# 569 F:\coffee-beans\images\mixed\IMAG1000.jpg
# 570 F:\coffee-beans\images\mixed\IMAG1001.jpg
# 571 F:\coffee-beans\images\mixed\IMAG1002.jpg
# 572 F:\coffee-beans\images\mixed\IMAG1003.jpg
# 573 F:\coffee-beans\images\mixed\IMAG1004.jpg
# 574 F:\coffee-beans\images\mixed\IMAG1005.jpg
# 575 F:\coffee-beans\images\mixed\IMAG1006.jpg
# 576 F:\coffee-beans\images\mixed\IMAG1007.jpg
# 577 F:\coffee-beans\images\mixed\IMAG1008.jpg
# 578 F:\coffee-beans\images\mixed\IMAG1009.jpg
# 579 F:\coffee-beans\images\mixed\IMAG1010.jpg
# 580 F:\coffee-beans\images\mixed\IMAG1011.jpg
# 581 F:\coffee-beans\images\mixed\IMAG1012.jpg
# 582 F:\coffee-beans\images\mixed\IMAG1013.jpg
# 583 F:\coffee-beans\images\mixed\IMAG1014.jpg
# 584 F:\coffee-beans\images\mixed\IMAG1015.jpg
# 585 F:\coffee-beans\images\mixed\IMAG1016.jpg
# 586 F:\coffee-beans\images\mixed\IMAG1017.jpg
# 587 F:\coffee-beans\images\mixed\IMAG1018.jpg
# 588 F:\coffee-beans\images\mixed\IMAG1019.jpg
# 589 F:\coffee-beans\images\mixed\IMAG1020.jpg
# 590 F:\coffee-beans\images\mixed\IMAG1021.jpg
# 591 F:\coffee-beans\images\mixed\IMAG1022.jpg
# 592 F:\coffee-beans\images\mixed\IMAG1023.jpg
# 593 F:\coffee-beans\images\mixed\IMAG1024.jpg
# 594 F:\coffee-beans\images\mixed\IMAG1025.jpg
# 595 F:\coffee-beans\images\mixed\IMAG1026.jpg
# 596 F:\coffee-beans\images\mixed\IMAG1027.jpg
# 597 F:\coffee-beans\images\mixed\IMAG1028.jpg
# 598 F:\coffee-beans\images\mixed\IMAG1029.jpg
# 599 F:\coffee-beans\images\mixed\IMAG1030.jpg
# 600 F:\coffee-beans\images\mixed\IMAG1031.jpg
# 601 F:\coffee-beans\images\mixed\IMAG1032.jpg
# 602 F:\coffee-beans\images\mixed\IMAG1033.jpg
# 603 F:\coffee-beans\images\mixed\IMAG1034.jpg
# 604 F:\coffee-beans\images\mixed\IMAG1035.jpg
# 605 F:\coffee-beans\images\mixed\IMAG1036.jpg
# 606 F:\coffee-beans\images\mixed\IMAG1037.jpg
# 607 F:\coffee-beans\images\mixed\IMAG1038.jpg
# 608 F:\coffee-beans\images\mixed\IMAG1039.jpg
# 609 F:\coffee-beans\images\mixed\IMAG1040.jpg
# 610 F:\coffee-beans\images\mixed\IMAG1041.jpg
# 611 F:\coffee-beans\images\mixed\IMAG1042.jpg
# 612 F:\coffee-beans\images\mixed\IMAG1043.jpg
# 613 F:\coffee-beans\images\mixed\IMAG1044.jpg
# 614 F:\coffee-beans\images\mixed\IMAG1045.jpg
# 615 F:\coffee-beans\images\mixed\IMAG1046.jpg
# 616 F:\coffee-beans\images\mixed\IMAG1047.jpg
# 617 F:\coffee-beans\images\mixed\IMAG1048.jpg
# 618 F:\coffee-beans\images\mixed\IMAG1049.jpg
# 619 F:\coffee-beans\images\mixed\IMAG1050.jpg
# 620 F:\coffee-beans\images\mixed\IMAG1051.jpg
# 621 F:\coffee-beans\images\mixed\IMAG1052.jpg
# 622 F:\coffee-beans\images\mixed\IMAG1053.jpg
# 623 F:\coffee-beans\images\mixed\IMAG1054.jpg
# 624 F:\coffee-beans\images\mixed\IMAG1055.jpg
# 625 F:\coffee-beans\images\mixed\IMAG1056.jpg
# 626 F:\coffee-beans\images\mixed\IMAG1057.jpg
# 627 F:\coffee-beans\images\mixed\IMAG1058.jpg
# 628 F:\coffee-beans\images\mixed\IMAG1059.jpg
# 629 F:\coffee-beans\images\mixed\IMAG1060.jpg
# 630 F:\coffee-beans\images\mixed\IMAG1061.jpg
# 631 F:\coffee-beans\images\mixed\IMAG1062.jpg
# 632 F:\coffee-beans\images\mixed\IMAG1063.jpg
# 633 F:\coffee-beans\images\mixed\IMAG1064.jpg
# 634 F:\coffee-beans\images\mixed\IMAG1065.jpg
# 635 F:\coffee-beans\images\mixed\IMAG1066.jpg
# 636 F:\coffee-beans\images\mixed\IMAG1067.jpg
# 637 F:\coffee-beans\images\mixed\IMAG1068.jpg
# 638 F:\coffee-beans\images\mixed\IMAG1069.jpg
# 639 F:\coffee-beans\images\mixed\IMAG1070.jpg
# 640 F:\coffee-beans\images\mixed\IMAG1071.jpg
# 641 F:\coffee-beans\images\mixed\IMAG1072.jpg
# 642 F:\coffee-beans\images\mixed\IMAG1073.jpg
# 643 F:\coffee-beans\images\mixed\IMAG1074.jpg
# 644 F:\coffee-beans\images\mixed\IMAG1075.jpg
# 645 F:\coffee-beans\images\mixed\IMAG1076.jpg
# 646 F:\coffee-beans\images\mixed\IMAG1077.jpg
# 647 F:\coffee-beans\images\mixed\IMAG1078.jpg
# 648 F:\coffee-beans\images\mixed\IMAG1079.jpg
# 649 F:\coffee-beans\images\mixed\IMAG1080.jpg
# 650 F:\coffee-beans\images\mixed\IMAG1081.jpg
# 651 F:\coffee-beans\images\mixed\IMAG1082.jpg

# %%
f = open(os.path.join(rootpath,'labels_labelstudio_format','tasks.json'), "w")
f.write(json.dumps(resultDict))
f.close()

# %%
for xmlFilei,xmlFilePath in enumerate(xmlFilePaths.values()):
    f = open(xmlFilePath, 'r', encoding='utf-8')
    xmlContent = f.read()
    f.close()
    tree = etree.fromstring(xmlContent)
    singleImageDict = {}
    print(xmlFilePath)
    #print(recursive_dict(tree))
    imageFilePath = list(tree.iter("path"))[0].text
    originalSize = recursive_dict(list(tree.iter("size"))[0])[1]
    originalSizeDict = {"original_width": originalSize['width'], "original_height": originalSize['height']}
    newImageFilePath = imageFilePath.replace(rootpath,newWebPathBase).replace(replaceSourcePath,newWebPathBase).replace('\\','/')
    #http://192.168.10.200/coffeebeans/images/bad/IMAG0605.jpg
    singleImageDict['data'] = {'image': newImageFilePath}
    predictionDictBase = {**{
        "type": "rectanglelabels",        
        "from_name": "label", "to_name": "image",
        "image_rotation": 0,
    }, **originalSizeDict}
    annotatedObjs = []
    #print(predictionDictBase)
    for keyi, element in enumerate(tree.iter("object")):
        #print("keyi is {}".format(keyi))
        elementDict = recursive_dict(element)
        """
            {
            "id": "result2",
            "type": "rectanglelabels",        
            "from_name": "label", "to_name": "image",
            "original_width": 600, "original_height": 403,
            "image_rotation": 0,
            "value": {
                "rotation": 0,          
                "x": 75.47, "y": 82.33,
                "width": 5.74, "height": 7.40,
                "rectanglelabels": ["Car"]
                }
            }
        """
        coffeeObjDict = (merge_two_dicts(
            predictionDictBase,
            {
                'id': 'result'+str(keyi+1),
                'value': {
                "rotation": 0,
                'x':int(elementDict[1]['bndbox']['xmin'])/int(originalSize['width'])*100,
                'y':int(elementDict[1]['bndbox']['ymin'])/int(originalSize['height'])*100,
                'width':(int(elementDict[1]['bndbox']['xmax']) - int(elementDict[1]['bndbox']['xmin']))
                    /int(originalSize['width'])*100,
                'height':( int(elementDict[1]['bndbox']['ymax']) - int(elementDict[1]['bndbox']['ymin']))
                    /int(originalSize['height'])*100,
                "rectanglelabels": [elementDict[1]['name']]
            }}
        ))
        annotatedObjs.append(coffeeObjDict)
        #display(elementDict)
        break
    singleImageDict['annotations'] = [{'result':annotatedObjs}]
    singleImageDict['id'] = xmlFilei+1
    resultDict.append(singleImageDict)
    break
#display(resultDict)
#break

# %% [markdown]
# # Rename Filenames in Label-Studio

# %%
import requests
import os
from IPython.display import display
session_requests = requests.session()
session_requests.headers.update({'Authorization': 'Token 21def27b3c847debd02963eb70a0db33b6375991'})
r = session_requests.get('http://192.168.10.200:8081/api/projects/1/tasks?page_size=9999&page=1')
rawSrcAnnotations = r.json()
website_prefix = "http://192.168.10.200/coffeebeans/images/"
toPatchurl = "http://192.168.10.200:8081/api/tasks/{}/"
for singleImageData in rawSrcAnnotations:
    imageFilePath = singleImageData['data']['image']
    newImageFilePath = imageFilePath.replace(website_prefix,"")
    print("handling id #{} for orig url is {}".format(singleImageData['id'], imageFilePath))
    folder, filename = newImageFilePath.split("/")
    newImageFilePath = "{}{}-{}".format(website_prefix, folder, filename)
    singleImageData['data']['image'] = newImageFilePath
    singleToPatchurl = toPatchurl.format(singleImageData['id'])
    update_req = session_requests.patch(url=singleToPatchurl, json=singleImageData)
    #display(singleImageData, singleToPatchurl, update_req)
    #annotations = singleImageData['annotations'][0]
    #<x_center> <y_center> <width> <height>
    #for annotation in annotations:
# Out:
# ages/good/IMAG0551.jpg
# handling id #271 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0550.jpg
# handling id #270 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0549.jpg
# handling id #269 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0548.jpg
# handling id #268 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0547.jpg
# handling id #267 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0546.jpg
# handling id #266 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0545.jpg
# handling id #265 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0544.jpg
# handling id #264 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0543.jpg
# handling id #263 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0538.jpg
# handling id #262 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0536.jpg
# handling id #261 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0535.jpg
# handling id #260 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0534.jpg
# handling id #259 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0533.jpg
# handling id #258 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0531.jpg
# handling id #257 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0523.jpg
# handling id #256 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0515.jpg
# handling id #255 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0514.jpg
# handling id #254 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0512.jpg
# handling id #253 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0511.jpg
# handling id #252 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0510.jpg
# handling id #251 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0509.jpg
# handling id #250 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0508.jpg
# handling id #249 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0507.jpg
# handling id #248 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0506.jpg
# handling id #247 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0505.jpg
# handling id #246 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0504.jpg
# handling id #245 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0503.jpg
# handling id #244 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0502.jpg
# handling id #243 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0501.jpg
# handling id #242 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0500.jpg
# handling id #241 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0499.jpg
# handling id #240 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0498.jpg
# handling id #239 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0497.jpg
# handling id #238 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0496.jpg
# handling id #237 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0495.jpg
# handling id #236 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0494.jpg
# handling id #235 for orig url is http://192.168.10.200/coffeebeans/images/good/IMAG0493.jpg
# handling id #229 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155352.jpg
# handling id #228 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155343.jpg
# handling id #227 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155336.jpg
# handling id #226 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155328.jpg
# handling id #225 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155323.jpg
# handling id #224 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155317.jpg
# handling id #223 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155310.jpg
# handling id #222 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155304.jpg
# handling id #221 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155258.jpg
# handling id #220 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155246.jpg
# handling id #219 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155219.jpg
# handling id #218 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155109.jpg
# handling id #217 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155104.jpg
# handling id #216 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155056.jpg
# handling id #215 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155048.jpg
# handling id #214 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155034.jpg
# handling id #213 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155028.jpg
# handling id #212 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155018.jpg
# handling id #211 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155008.jpg
# handling id #210 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_155001.jpg
# handling id #209 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154952.jpg
# handling id #208 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154830.jpg
# handling id #207 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154806.jpg
# handling id #206 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154746.jpg
# handling id #205 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154730.jpg
# handling id #204 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154719.jpg
# handling id #203 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154709.jpg
# handling id #202 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154645.jpg
# handling id #201 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154526.jpg
# handling id #200 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154512.jpg
# handling id #199 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154505.jpg
# handling id #198 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154457.jpg
# handling id #197 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154436.jpg
# handling id #196 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154423.jpg
# handling id #195 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154413.jpg
# handling id #194 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154405.jpg
# handling id #193 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154356.jpg
# handling id #192 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154348.jpg
# handling id #191 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154216.jpg
# handling id #190 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154204.jpg
# handling id #189 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154150.jpg
# handling id #188 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154128.jpg
# handling id #187 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154100.jpg
# handling id #186 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154053.jpg
# handling id #185 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_154046.jpg
# handling id #184 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153930.jpg
# handling id #183 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153923.jpg
# handling id #182 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153919.jpg
# handling id #181 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153912.jpg
# handling id #180 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153905.jpg
# handling id #179 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153900.jpg
# handling id #178 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153855.jpg
# handling id #177 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153836.jpg
# handling id #176 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153832.jpg
# handling id #175 for orig url is http://192.168.10.200/coffeebeans/images/good/20210420_153827.jpg
# handling id #174 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0782.jpg
# handling id #173 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0781.jpg
# handling id #172 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0780.jpg
# handling id #171 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0779.jpg
# handling id #170 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0778.jpg
# handling id #169 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0777.jpg
# handling id #168 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0776.jpg
# handling id #167 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0775.jpg
# handling id #166 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0774.jpg
# handling id #165 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0773.jpg
# handling id #164 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0772.jpg
# handling id #163 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0771.jpg
# handling id #162 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0770.jpg
# handling id #161 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0769.jpg
# handling id #160 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0768.jpg
# handling id #159 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0767.jpg
# handling id #158 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0766.jpg
# handling id #157 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0765.jpg
# handling id #156 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0764.jpg
# handling id #155 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0763.jpg
# handling id #154 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0762.jpg
# handling id #153 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0761.jpg
# handling id #152 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0760.jpg
# handling id #151 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0759.jpg
# handling id #150 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0758.jpg
# handling id #149 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0757.jpg
# handling id #148 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0756.jpg
# handling id #147 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0755.jpg
# handling id #146 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0754.jpg
# handling id #144 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0752.jpg
# handling id #143 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0751.jpg
# handling id #142 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0750.jpg
# handling id #141 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0749.jpg
# handling id #140 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0748.jpg
# handling id #139 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0746.jpg
# handling id #138 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0745.jpg
# handling id #137 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0744.jpg
# handling id #136 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0743.jpg
# handling id #135 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0742.jpg
# handling id #134 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0741.jpg
# handling id #133 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0740.jpg
# handling id #132 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0739.jpg
# handling id #131 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0738.jpg
# handling id #130 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0737.jpg
# handling id #129 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0736.jpg
# handling id #128 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0735.jpg
# handling id #127 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0734.jpg
# handling id #126 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0732.jpg
# handling id #125 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0707.jpg
# handling id #124 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0706.jpg
# handling id #123 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0705.jpg
# handling id #122 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0704.jpg
# handling id #121 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0703.jpg
# handling id #120 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0702.jpg
# handling id #119 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0701.jpg
# handling id #118 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0700.jpg
# handling id #117 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0699.jpg
# handling id #116 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0698.jpg
# handling id #115 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0697.jpg
# handling id #114 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0696.jpg
# handling id #113 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0695.jpg
# handling id #112 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0694.jpg
# handling id #108 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0688.jpg
# handling id #107 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0687.jpg
# handling id #102 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0689.jpg
# handling id #100 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0683.jpg
# handling id #99 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0682.jpg
# handling id #97 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0680.jpg
# handling id #96 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0679.jpg
# handling id #95 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0677.jpg
# handling id #94 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0676.jpg
# handling id #93 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0675.jpg
# handling id #92 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0674.jpg
# handling id #91 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0673.jpg
# handling id #90 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0672.jpg
# handling id #89 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0671.jpg
# handling id #88 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0670.jpg
# handling id #87 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0669.jpg
# handling id #86 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0668.jpg
# handling id #85 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0667.jpg
# handling id #83 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0665.jpg
# handling id #82 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0664.jpg
# handling id #81 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0663.jpg
# handling id #77 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0659.jpg
# handling id #76 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0658.jpg
# handling id #75 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0657.jpg
# handling id #74 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0656.jpg
# handling id #73 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0655.jpg
# handling id #72 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0654.jpg
# handling id #71 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0653.jpg
# handling id #70 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0652.jpg
# handling id #69 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0651.jpg
# handling id #68 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0650.jpg
# handling id #53 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0634.jpg
# handling id #52 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0633.jpg
# handling id #51 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0632.jpg
# handling id #50 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0631.jpg
# handling id #46 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0627.jpg
# handling id #45 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0626.jpg
# handling id #44 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0625.jpg
# handling id #39 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0620.jpg
# handling id #38 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0619.jpg
# handling id #35 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0616.jpg
# handling id #34 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0615.jpg
# handling id #33 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0614.jpg
# handling id #32 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0613.jpg
# handling id #31 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0612.jpg
# handling id #17 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0725.jpg
# handling id #16 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0724.jpg
# handling id #15 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0723.jpg
# handling id #14 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0722.jpg
# handling id #13 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0721.jpg
# handling id #12 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0720.jpg
# handling id #11 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0718.jpg
# handling id #10 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0717.jpg
# handling id #9 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0716.jpg
# handling id #8 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0715.jpg
# handling id #7 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0714.jpg
# handling id #6 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0713.jpg
# handling id #5 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0712.jpg
# handling id #4 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0711.jpg
# handling id #3 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0710.jpg
# handling id #2 for orig url is http://192.168.10.200/coffeebeans/images/bad/IMAG0709.jpg

# %% [markdown]
# # Update task for annotations

# %%
import requests
import os
from IPython.display import display
session_requests = requests.session()
session_requests.headers.update({'Authorization': 'Token 21def27b3c847debd02963eb70a0db33b6375991'})
r = session_requests.get('http://192.168.10.200:8081/api/projects/1/tasks?page_size=9999&page=1')
rawSrcAnnotations = r.json()
website_prefix = "http://192.168.10.200/coffeebeans/images/"
toPatchurl = "http://192.168.10.200:8081/api/tasks/{}/"
taskids = [r['id'] for r in rawSrcAnnotations]
#display(taskids)
for singleImageData in rawSrcAnnotations:
    singleImageData['project'] = 2
    singleToPatchurl = toPatchurl.format(singleImageData['id'])
    update_req = session_requests.patch(url=singleToPatchurl, json=singleImageData)
