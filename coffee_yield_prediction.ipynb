# %% [markdown]
# # 參考文獻
#
# *   [氣象資料開放平台](https://opendata.cwb.gov.tw/index)
# *   [農情調查](https://data.coa.gov.tw/Query/ServiceDetail.aspx?id=038)
# *   [農情預測](https://data.coa.gov.tw/Query/ServiceTransDetail.aspx?id=4P84xEv6hd22)
# *   CWB-CA3A0F5C-455E-436A-9FB7-530DA1A044E7
#
# # Note
#
# 統計中咖啡期作每年都只有一期全年；5-6年生；每年收成月份 不定
# 產量資料最早在97年；氣候天氣資料應該要從92開始

# %%
from lxml import etree
from scipy.spatial import distance
import matplotlib.pyplot as plt
import requests
import numpy as np
import pandas as pd
import tensorflow as tf
import urllib,dask,lxml,re,os,time,io
from IPython.display import display, HTML
from pathos.helpers import cpu_count
from dask.diagnostics import ProgressBar

# %% [markdown]
# # 蒐集資料及預處理資料

# %% [markdown]
# ## 產量資料

# %%
def get_yield_data_df():
  yield_data_raw = [dask.delayed(requests.get)("https://data.coa.gov.tw/Service/OpenData/FromM/TownCropData.aspx?cropCode=337&year="+str(n)) for n in range(97,109)]
  yield_data_raw = dask.compute(*yield_data_raw)
  for i,x in enumerate(yield_data_raw): yield_data_raw[i].encoding = 'UTF-8'
  yield_data_json = [yd.json() for yd in yield_data_raw]
  yield_data_df = list()
  for sublist in yield_data_json: yield_data_df.extend(sublist)
  yield_data_df = pd.DataFrame.from_dict(yield_data_df)
  yield_data_df['年度'] = yield_data_df['年度'].astype(int)
  yield_data_df['yield_year'] = yield_data_df['年度']+1911
  yield_data_df['yield_year_str'] = yield_data_df['yield_year'].astype(str)
  return yield_data_df

# %%
yield_data_df = get_yield_data_df().rename(columns={"縣市": "city", "鄉鎮": "district"})
yield_data_df['city'] = yield_data_df['city'].str.replace(pat="台", repl="臺")
#yield_data_df['city'] = yield_data_df['city'].str.replace(pat="巿", repl="市")
#yield_data_df['district'] = yield_data_df['district'].str.replace(pat="巿", repl="市")
yield_data_df['district'] = yield_data_df['district'].str.replace(pat="台", repl="臺")
display(yield_data_df)
# Out:
#        年度  期作 city district  作物代碼  作物  收穫面積(公頃)  種植面積(公頃)  每公頃收穫量(公斤)  \
# 0      97  全年  臺北市      文山區  337   咖啡      0.10      0.10      5000.0
# 1      97  全年  新北市      石碇區  337   咖啡      1.00      1.00        50.0
# 2      97  全年  新北市      石門區  337   咖啡      0.00      1.20         0.0
# 3      97  全年  新北市      三峽區  337   咖啡      0.00      0.80         0.0
# 4      97  全年  桃園市      龍潭區  337   咖啡      0.20      1.20       800.0
# ...   ...  ..  ...      ...   ...  ..       ...       ...         ...
# 1537  108  全年  臺東縣      達仁鄉  337   咖啡     31.28     31.28      1100.0
# 1538  108  全年  臺東縣      卑南鄉  337   咖啡     17.92     17.92      1100.0
# 1539  108  全年  臺東縣      東河鄉  337   咖啡     11.86     12.31       790.0
# 1540  108  全年  臺東縣      池上鄉  337   咖啡      9.18      9.18       900.0
# 1541  108  全年  金門縣      金寧鄉  337   咖啡      0.05      0.05       360.0
#
#        收量(公斤)  yield_year yield_year_str
# 0       500.0        2008           2008
# 1        50.0        2008           2008
# 2         0.0        2008           2008
# 3         0.0        2008           2008
# 4       160.0        2008           2008
# ...       ...         ...            ...
# 1537  34408.0        2019           2019
# 1538  19712.0        2019           2019
# 1539   9369.0        2019           2019
# 1540   8262.0        2019           2019
# 1541     18.0        2019           2019
#
# [1542 rows x 12 columns]

# %% [markdown]
# ### 找出有產量資料中有完整資料（所有年度都有）的鄉鎮市區

# %%
completed_cases_stations_df = yield_data_df.groupby(['city','district'])['收量(公斤)'].agg(['mean', 'count']).sort_values(by=['count','mean'],ascending=False).reset_index(drop=False)
completed_cases_stations_df = completed_cases_stations_df[completed_cases_stations_df['count']==max(completed_cases_stations_df['count'])]
#completed_cases_stations = completed_cases_stations_df['鄉鎮'].to_list()
display(yield_data_df.head(n=5)) #.head(n=50)
display(completed_cases_stations_df)
completed_cases_stations_df = completed_cases_stations_df[['city','district']]
#display(completed_cases_stations_df.head(n=5)) #.head(n=50)
# Out:
#    年度  期作 city district  作物代碼  作物  收穫面積(公頃)  種植面積(公頃)  每公頃收穫量(公斤)  收量(公斤)  \
# 0  97  全年  臺北市      文山區  337   咖啡       0.1       0.1      5000.0   500.0
# 1  97  全年  新北市      石碇區  337   咖啡       1.0       1.0        50.0    50.0
# 2  97  全年  新北市      石門區  337   咖啡       0.0       1.2         0.0     0.0
# 3  97  全年  新北市      三峽區  337   咖啡       0.0       0.8         0.0     0.0
# 4  97  全年  桃園市      龍潭區  337   咖啡       0.2       1.2       800.0   160.0
#
#    yield_year yield_year_str
# 0        2008           2008
# 1        2008           2008
# 2        2008           2008
# 3        2008           2008
# 4        2008           2008
#    city district          mean  count
# 0   屏東縣     三地門鄉  76045.166667     12
# 1   雲林縣      古坑鄉  64502.916667     12
# 2   南投縣      國姓鄉  62808.583333     12
# 3   臺南市      東山區  60991.833333     12
# 4   嘉義縣     阿里山鄉  52203.666667     12
# ..  ...      ...           ...    ...
# 66  屏東縣      屏東市    128.666667     12
# 67  臺北市      文山區    121.166667     12
# 68  宜蘭縣      員山鄉     56.583333     12
# 69  南投縣      集集鎮     45.750000     12
# 70  新北市      石碇區     37.250000     12
#
# [71 rows x 4 columns]

# %% [markdown]
# ### 各鄉鎮市區地理中心資訊

# %%
district_center_df = requests.get("http://quality.data.gov.tw/dq_download_csv.php?nid=25489&md5_url=a85eb04185242dd82bf3db71756eb6da")
district_center_df.encoding = 'UTF-8'
district_center_df = district_center_df.text
district_center_df = io.StringIO(district_center_df) #.replace("巿","市")
district_center_df = pd.read_csv(district_center_df,encoding='UTF-8')
district_center_df['city'] = district_center_df['行政區名'].str.extract("(.{2}[縣|市]{1}){1}?")
district_center_df['district'] = district_center_df['行政區名'].str.extract(".{2}[縣|市]{1}([\u4E00-\u9FFF]{1,5}?[鄉鎮市區]{1,2}){1}?")
#district_center_df['district'].at[district_center_df['district']=='彰化市'] = '彰化巿'

#district_center_df.to_excel('R:/test.xlsx')
display(district_center_df)
district_center_df[district_center_df['district']=='彰化市']
# Out:
#        行政區名  _x0033_碼郵遞區號       中心點經度      中心點緯度  \
# 0    臺北市中正區           100  121.519884  25.032405
# 1    臺北市大同區           103  121.513042  25.063424
# 2    臺北市中山區           104  121.538160  25.069699
# 3    臺北市松山區           105  121.557588  25.059991
# 4    臺北市大安區           106  121.543445  25.026770
# ..      ...           ...         ...        ...
# 366  花蓮縣瑞穗鄉           978  121.407347  23.515612
# 367  花蓮縣萬榮鄉           979  121.318953  23.727726
# 368  花蓮縣玉里鎮           981  121.360448  23.371436
# 369  花蓮縣卓溪鄉           982  121.180422  23.390629
# 370  花蓮縣富里鄉           983  121.298049  23.196721
#
#                                               TGOS_URL city district
# 0    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺北市      中正區
# 1    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺北市      大同區
# 2    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺北市      中山區
# 3    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺北市      松山區
# 4    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺北市      大安區
# ..                                                 ...  ...      ...
# 366  http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  花蓮縣      瑞穗鄉
# 367  http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  花蓮縣      萬榮鄉
# 368  http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  花蓮縣      玉里鎮
# 369  http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  花蓮縣      卓溪鄉
# 370  http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  花蓮縣      富里鄉
#
# [371 rows x 7 columns]
#        行政區名  _x0033_碼郵遞區號       中心點經度      中心點緯度  \
# 141  彰化縣彰化市           500  120.569421  24.075329
#
#                                               TGOS_URL city district
# 141  http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  彰化縣      彰化市

# %% [markdown]
# ### 各氣象站基本資料

# %%
def get_weather_station_attrs_df():
  weather_station_attrs = requests.get("https://e-service.cwb.gov.tw/wdps/obs/state.htm")
  weather_station_attrs.encoding = 'UTF-8'
  weather_station_attrs = weather_station_attrs.text.replace(
      re.match(pattern="(<meta{1}[\w\d\s\W\D\S]+</style>{1})", string=weather_station_attrs.text)[0],""
  )
  weather_station_etree = etree.HTML(weather_station_attrs)
  r = weather_station_etree.xpath("//div[@id='existing_station']/table")[0]
  weather_station_existing_df = pd.read_html(etree.tostring(r))[0]
  weather_station_existing_df['status'] = "現存"
  r = weather_station_etree.xpath("//div[@id='revoked_station']/table")[0]
  weather_station_revoked_df = pd.read_html(etree.tostring(r))[0]
  weather_station_revoked_df['status'] = '已撤站'
  weather_station_attr_df = pd.concat([weather_station_existing_df,weather_station_revoked_df]).reset_index(drop=True).rename(columns={'站號':'stationid','站名':'stationname','城市':'city'})
  #weather_station_attr_df['city'] = weather_station_attr_df['城市']
  weather_station_attr_df['district'] = weather_station_attr_df['地址'].str.extract(r"([\u4E00-\u9FFF]{1,5}?[鄉鎮市區]{1,2}){1}?")
  weather_station_attr_df['begin_year'] = weather_station_attr_df['資料起始日期'].str.extract("(\d+)\/{1}").astype(int)
  return weather_station_attr_df

weather_station_attr_df_preferred = get_weather_station_attrs_df()
weather_station_attr_df_preferred = weather_station_attr_df_preferred[weather_station_attr_df_preferred['status']=='現存']
weather_station_attr_df_preferred = weather_station_attr_df_preferred[weather_station_attr_df_preferred['begin_year']<=2003].sort_values(by=['city','district'],ascending=False)
display(weather_station_attr_df_preferred)
#display(set(weather_station_attr_df_preferred['城市'].tolist()) )
#weather_station_attr_df_preferred = pd.merge(left=weather_station_attr_df_preferred,right=completed_cases_stations_df,how="inner")
# Out:
#     stationid stationname  海拔高度(m)          經度         緯度 city  \
# 591    C1V160        達卡努瓦   1040.0  120.705319  23.279811  高雄市
# 383    C0V310          美濃     46.0  120.519153  22.898742  高雄市
# 381    C0V250          甲仙    298.0  120.591758  23.080106  高雄市
# 386    C0V370         古亭坑     74.0  120.401947  22.893178  高雄市
# 599    C1V390          尖山     60.0  120.367789  22.813153  高雄市
# ..        ...         ...      ...         ...        ...  ...
# 509    C1H900          清流    934.0  120.962997  24.080775  南投縣
# 514    C1I020          萬大   1120.0  121.132261  23.979817  南投縣
# 515    C1I030          武界    948.0  121.052483  23.913225  南投縣
# 533    C1I320         奧萬大   1275.0  121.178556  23.952956  南投縣
# 534    C1I330         楓樹林   1266.0  121.076117  23.986803  南投縣
#
#                                 地址      資料起始日期 撤站日期  \
# 591                      那瑪夏區達卡努瓦里  1992/01/21  NaN
# 383  美濃區福安里中山路二段204巷65號(美濃區福安國小後方)  1992/01/22  NaN
# 381            甲仙區(甲仙國民中學操場後方小山丘上)  1992/01/21  NaN
# 386                         田寮區古亭里  1992/05/01  NaN
# 599       燕巢區尖山里尖山巷11之1號(燕巢國小尖山分校)  1992/01/22  NaN
# ..                             ...         ...  ...
# 509                         仁愛鄉互助村  1991/12/12  NaN
# 514                  仁愛鄉親愛村萬大水庫宿舍旁  1992/05/12  NaN
# 515                         仁愛鄉法治村  1992/05/03  NaN
# 533             仁愛鄉奧萬大森林遊樂區內(員工宿舍)  2002/05/15  NaN
# 534      仁愛鄉埔里事業區107林班地(臺14線近埔里市區)  2002/05/01  NaN
#
#                                                     備註  原站號  新站號 status  \
# 591  原名為民生(達卡努瓦)，於2015/10/13更名為達卡努瓦。本站於2015/10/13起進...  NaN  NaN     現存
# 383               本站於 2013/6/15 進行儀器汰換，並於2013/8/1完成驗收。  NaN  NaN     現存
# 381                本站於2013/3/13進行儀器汰換，並於2013/4/18完成驗收。  NaN  NaN     現存
# 386         本站因儀器汰換，自2013/8/31起暫停資料提供，並於2013/12/1完成驗收。  NaN  NaN     現存
# 599                 本站於2013/9/3進行儀器汰換，並於2013/12/1完成驗收。  NaN  NaN     現存
# ..                                                 ...  ...  ...    ...
# 509              本站於2015/7/24起進行儀器汰換，並於2015/12/31完成驗收。  NaN  NaN     現存
# 514              本站於2015/8/11起進行儀器汰換，並於2015/12/31完成驗收。  NaN  NaN     現存
# 515              本站於2015/8/14起進行儀器汰換，並於2015/12/31完成驗收。  NaN  NaN     現存
# 533        短距離移位。本站於2015/8/19起進行儀器汰換，並於2015/12/31完成驗收。  NaN  NaN     現存
# 534               本站於2015/8/3起進行儀器汰換，並於2015/12/31完成驗收。  NaN  NaN     現存
#
#     district  begin_year
# 591     那瑪夏區        1992
# 383      美濃區        1992
# 381      甲仙區        1992
# 386      田寮區        1992
# 599      燕巢區        1992
# ..       ...         ...
# 509      仁愛鄉        1991
# 514      仁愛鄉        1992
# 515      仁愛鄉        1992
# 533      仁愛鄉        2002
# 534      仁愛鄉        2002
#
# [167 rows x 15 columns]

# %% [markdown]
# ## 從產量資料找出相對應的氣象測站
# 要將產量資料和測站觀測資料配對串連

# %%
#一年觀測資料 一年觀測資料-局屬地面測站觀測資料 https://opendata.cwb.gov.tw/dataset/climate/C-B0024-002
#每月氣象-過去9年局屬地面測站每月氣象資料 https://opendata.cwb.gov.tw/dataset/climate/C-B0026-002
#每日雨量-過去9年局屬地面測站每日雨量資料 https://opendata.cwb.gov.tw/dataset/climate/C-B0025-002
#抓資料介面 https://opendata.cwb.gov.tw/dist/opendata-swagger.html?urls.primaryName=openAPI#/
#https://e-service.cwb.gov.tw/HistoryDataQuery/
#view-source:https://e-service.cwb.gov.tw/HistoryDataQuery/QueryDataController.do?command=viewMain

stationinfos = list()
succeed_match_stations = list()
succeed_match_stations_df = list()
failed_match_stations = list()
stationsinfos_mismatched = list()
mismatched_stations_df = list()
duplicated_match_stations = list()
paddedmonths = [str(m).rjust(2, '0') for m in range(1,13)]
"""
stationinfos a list of dict where its content is as follows

    {'stationid': 'C0A920',
      'stationname': '富貴角',
      'city': '新北市',
      'district': '石門區',
      'month': '07',
      'year': '2008',
      'yield_year': 2008},

succeed_match_stations: a list of the row number of yield data where there is a matched station

succeed_match_stations_df

failed_match_stations: a list of the row number of yield data where there is a mismatched station

duplicated_match_stations: a list of the row number of yield data where there are multiple matched stations(multiple stations in a district)
"""

for yield_data_df_n in range(len(yield_data_df.index)):
  temp_basis_df = yield_data_df.loc[[yield_data_df_n],['city','district','yield_year']].reset_index(drop=True)
  print("yield_data_df_n={} and temp_basis_df is:".format(yield_data_df_n))
  #display(temp_basis_df)
  temp_basis_series = yield_data_df.loc[yield_data_df_n,['city','district','yield_year']]
  targetfetchyears = list(range(temp_basis_series['yield_year']-5, temp_basis_series['yield_year']+1))
  temp_basis_df_2 = temp_basis_df.drop(columns=['yield_year']).reset_index(drop=True)
  #print("temp_basis_df_2 is:")
  #display(temp_basis_df_2)
  needed_station_df = pd.merge(left=weather_station_attr_df_preferred,right=temp_basis_df_2,how='inner')
  if len(needed_station_df.index)>0:
    """
    needed_station_df found 讀取天氣觀測資料
    """
    succeed_match_stations.append(yield_data_df_n)
    print("needed_station_df found")
    if len(needed_station_df.index)>1: duplicated_match_stations.append(yield_data_df_n)
    needed_station_df_simplified = needed_station_df.loc[:,['stationid','stationname','city','district']]
    needed_station_df_simplified = pd.concat([needed_station_df_simplified.assign(month=m) for m in paddedmonths]  ).reset_index(drop=True)
    needed_station_df_simplified = pd.concat([needed_station_df_simplified.assign(year=str(y)) for y in targetfetchyears]  ).reset_index(drop=True)
    needed_station_df_simplified['matchingtype'] = 'samedistrict'
    stationinfos.extend(
        [{**nd,**temp_basis_df.to_dict('records')[0]} for nd in needed_station_df_simplified.to_dict('records')]
        )
  else:
    """
    needed_station_df not found, find nearest station instead
    """
    print("needed_station_df not found")
    failed_match_stations.append(yield_data_df_n)
    axis = pd.merge(left=district_center_df,right=temp_basis_df_2,how='inner')
    try:
      axis = axis.loc[:,['中心點經度','中心點緯度']].to_dict('records')[0]
    except Exception as wrongaxis:
      display(temp_basis_df_2)
      display(axis)
      print(str(wrongaxis))
      break
    #計算離產量資料鄉鎮市區最近的氣象站並且串接
    axis_np = list(axis.values())
    nearest_station_axis = weather_station_attr_df_preferred
    nearest_station_axis['combined_axis'] = nearest_station_axis.loc[:,['經度','緯度']].values.tolist()
    nearest_station_axis['distance'] = nearest_station_axis['combined_axis'].apply(distance.euclidean, v=axis_np)
    nearest_station_axis = nearest_station_axis.sort_values(by=['distance'], ascending=True).reset_index(drop=True).loc[[0],:].reset_index(drop=True)
    needed_station_df_simplified = temp_basis_df.rename(columns={'city':'yieldcity','district':'yielddistrict'}).reset_index(drop=True)
    needed_station_df_simplified = pd.concat([nearest_station_axis, needed_station_df_simplified], axis=1).reset_index(drop=True)
    mismatched_stations_df.append(needed_station_df_simplified)
    #display(nearest_station_axis)
    #display(needed_station_df_simplified)
    #break
    needed_station_df_simplified = pd.concat([needed_station_df_simplified.assign(month=m) for m in paddedmonths]  ).reset_index(drop=True)
    needed_station_df_simplified = pd.concat([needed_station_df_simplified.assign(year=str(y)) for y in targetfetchyears]  ).reset_index(drop=True)
    needed_station_df_simplified['matchingtype'] = 'nearest'
    needed_station_df_simplified = needed_station_df_simplified.loc[:,['stationid','stationname','city','district','month','year','yield_year']].to_dict('records')
    stationsinfos_mismatched.extend(needed_station_df_simplified)
  #if yield_data_df_n>11:
  #  break
  if False:
    urlencoded_name = urllib.parse.quote(temp_basis_df_for_mergeweather['stationname'][0], safe='~@#$&()*!+=:;,.?/\'', encoding='UTF-8').replace("%","%25")
    sinfo_weather_data_raw = "https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station={}&datepicker=-&stname={}".format(temp_basis_df_for_mergeweather['stationid'][0], urlencoded_name)
    station_info_message_ori = temp_basis_df_for_mergeweather.loc[:,['stationid','stationname','yield_year']].to_dict('records')[0]
    try:
      station_info_message = map(str,list(station_info_message_ori.values()))
      t = "processing "+" ".join(station_info_message+[sinfo_weather_data_raw])
    except Exception as joinerror:
      print(str(joinerror))
      display(temp_basis_df_for_mergeweather)
      display(station_info_message_ori)
      break
# Out:
# =1253 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1254 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1255 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1256 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1257 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1258 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1259 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1260 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1261 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1262 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1263 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1264 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1265 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1266 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1267 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1268 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1269 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1270 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1271 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1272 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1273 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1274 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1275 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1276 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1277 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1278 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1279 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1280 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1281 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1282 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1283 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1284 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1285 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1286 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1287 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1288 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1289 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1290 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1291 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1292 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1293 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1294 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1295 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1296 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1297 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1298 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1299 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1300 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1301 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1302 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1303 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1304 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1305 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1306 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1307 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1308 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1309 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1310 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1311 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1312 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1313 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1314 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1315 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1316 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1317 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1318 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1319 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1320 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1321 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1322 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1323 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1324 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1325 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1326 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1327 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1328 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1329 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1330 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1331 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1332 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1333 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1334 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1335 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1336 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1337 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1338 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1339 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1340 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1341 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1342 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1343 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1344 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1345 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1346 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1347 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1348 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1349 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1350 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1351 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1352 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1353 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1354 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1355 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1356 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1357 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1358 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1359 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1360 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1361 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1362 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1363 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1364 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1365 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1366 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1367 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1368 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1369 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1370 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1371 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1372 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1373 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1374 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1375 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1376 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1377 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1378 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1379 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1380 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1381 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1382 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1383 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1384 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1385 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1386 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1387 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1388 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1389 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1390 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1391 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1392 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1393 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1394 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1395 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1396 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1397 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1398 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1399 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1400 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1401 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1402 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1403 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1404 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1405 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1406 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1407 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1408 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1409 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1410 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1411 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1412 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1413 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1414 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1415 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1416 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1417 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1418 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1419 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1420 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1421 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1422 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1423 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1424 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1425 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1426 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1427 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1428 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1429 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1430 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1431 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1432 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1433 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1434 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1435 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1436 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1437 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1438 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1439 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1440 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1441 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1442 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1443 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1444 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1445 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1446 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1447 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1448 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1449 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1450 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1451 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1452 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1453 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1454 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1455 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1456 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1457 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1458 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1459 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1460 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1461 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1462 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1463 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1464 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1465 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1466 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1467 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1468 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1469 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1470 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1471 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1472 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1473 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1474 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1475 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1476 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1477 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1478 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1479 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1480 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1481 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1482 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1483 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1484 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1485 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1486 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1487 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1488 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1489 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1490 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1491 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1492 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1493 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1494 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1495 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1496 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1497 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1498 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1499 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1500 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1501 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1502 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1503 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1504 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1505 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1506 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1507 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1508 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1509 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1510 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1511 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1512 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1513 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1514 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1515 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1516 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1517 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1518 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1519 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1520 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1521 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1522 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1523 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1524 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1525 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1526 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1527 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1528 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1529 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1530 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1531 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1532 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1533 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1534 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1535 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1536 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1537 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1538 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1539 and temp_basis_df is:
# needed_station_df not found
# yield_data_df_n=1540 and temp_basis_df is:
# needed_station_df found
# yield_data_df_n=1541 and temp_basis_df is:
# needed_station_df not found

# %% [markdown]
# ### 各氣象站觀測資料

# %%
def get_station_monthly_data_retrieve(stationinfo):
  station_info_message = list(map(str,stationinfo.values()))
  try:
    #stationinfo = {'stationid':'466850','stationname':'五分山雷達站','year':'2021','month':'01'}
    stationinfo['urlencoded_name'] = urllib.parse.quote(stationinfo['stationname'], safe='~@#$&()*!+=:;,.?/\'', encoding='UTF-8').replace("%","%25")
    weather_data_raw = "https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station={}&datepicker={}-{}&stname={}".format(stationinfo['stationid'], stationinfo['year'], stationinfo['month'], stationinfo['urlencoded_name'])
    print("processing "+" ".join(station_info_message+[weather_data_raw] ))
    weather_data_raw = requests.get(weather_data_raw)
    weather_data_raw.encoding = 'UTF-8'
    return [weather_data_raw.text,stationinfo]
  except Exception as e:
    print("retrieving error at "+" ".join(station_info_message)+" for "+str(e))
    return ["retrieving error",stationinfo]

def get_station_monthly_data_parse(stationinfo):
  retrieved_text = stationinfo[0]
  stationinfo = stationinfo[1]
  station_info_message = map(str,list(stationinfo.values()))
  try:
    weather_data_etree = etree.HTML(retrieved_text)
    #觀測時間(day)	測站氣壓(hPa)	海平面氣壓(hPa)	測站最高氣壓(hPa)	測站最高氣壓時間(LST)	測站最低氣壓(hPa)	測站最低氣壓時間(LST)	氣溫(℃)	最高氣溫(℃)	最高氣溫時間(LST)	最低氣溫(℃)	最低氣溫時間(LST)	露點溫度(℃)	相對溼度(%)	最小相對溼度(%)	最小相對溼度時間(LST)	風速(m/s)	風向(360degree)	最大陣風(m/s)	最大陣風風向(360degree)	最大陣風風速時間(LST)	降水量(mm)	降水時數(hour)	最大十分鐘降水量(mm)	最大十分鐘降水量起始時間(LST)	最大六十分鐘降水量(mm)	最大六十分鐘降水量起始時間(LST)	日照時數(hour)	日照率(%)	全天空日射量(MJ/㎡)	能見度(km)	A型蒸發量(mm)	日最高紫外線指數	日最高紫外線指數時間(LST)	總雲量(0~10)
    r = weather_data_etree.xpath("//table[@id='MyTable']//tr[position()>2]")
    weather_data_df = [etree.tostring(tr, encoding='unicode') for tr in r]
    weather_data_df = "<table>"+"".join(weather_data_df)+"</table>"
    weather_data_df = pd.read_html(weather_data_df)[0]
    for key,value in stationinfo.items(): weather_data_df[key] = value
  except Exception as e:
    parsing_err_text = "parsing error at "+" ".join(station_info_message)+" for "+str(e)
    weather_data_df = parsing_err_text
    print(parsing_err_text)
  weather_data_df = "retrieving error at "+" ".join(station_info_message) if retrieved_text=="retrieving error" else weather_data_df
  return weather_data_df

# %% [markdown]
# ## 抓氣象觀測資料
# 花時間很長

# %%
get_station_monthly_data_parse(get_station_monthly_data_retrieve({**stationinfos[0], **{'year':'2004'}}))
# Out:
# processing C0A920 富貴角 新北市 石門區 01 2004 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
#     ObsTime  StnPres SeaPres StnPresMax StnPresMaxTime StnPresMin  \
# 0         1    995.4     ...          /            ...          /
# 1         2    996.4     ...          /            ...          /
# 2         3    996.7     ...          /            ...          /
# 3         4    996.3     ...          /            ...          /
# 4         5    995.4     ...          /            ...          /
# 5         6    996.3     ...          /            ...          /
# 6         7    998.9     ...          /            ...          /
# 7         8   1000.3     ...          /            ...          /
# 8         9    999.2     ...          /            ...          /
# 9        10    995.9     ...          /            ...          /
# 10       11    996.8     ...          /            ...          /
# 11       12    997.9     ...          /            ...          /
# 12       13    999.0     ...          /            ...          /
# 13       14    996.1     ...          /            ...          /
# 14       15    993.5     ...          /            ...          /
# 15       16    992.2     ...          /            ...          /
# 16       17    995.9     ...          /            ...          /
# 17       18    993.0     ...          /            ...          /
# 18       19    995.7     ...          /            ...          /
# 19       20    995.4     ...          /            ...          /
# 20       21    998.4     ...          /            ...          /
# 21       22    999.1     ...          /            ...          /
# 22       23    997.3     ...          /            ...          /
# 23       24   1000.7     ...          /            ...          /
# 24       25   1000.9     ...          /            ...          /
# 25       26    996.2     ...          /            ...          /
# 26       27    996.5     ...          /            ...          /
# 27       28    993.8     ...          /            ...          /
# 28       29    990.1     ...          /            ...          /
# 29       30    992.7     ...          /            ...          /
# 30       31    992.3     ...          /            ...          /
#
#    StnPresMinTime  Temperature T Max T Max Time  ... UVI Max Time  \
# 0             ...         15.5     /        ...  ...          ...
# 1             ...         15.0     /        ...  ...          ...
# 2             ...         15.8     /        ...  ...          ...
# 3             ...         18.6     /        ...  ...          ...
# 4             ...         20.0     /        ...  ...          ...
# 5             ...         17.4     /        ...  ...          ...
# 6             ...         16.2     /        ...  ...          ...
# 7             ...         15.8     /        ...  ...          ...
# 8             ...         16.9     /        ...  ...          ...
# 9             ...         18.1     /        ...  ...          ...
# 10            ...         14.6     /        ...  ...          ...
# 11            ...         12.1     /        ...  ...          ...
# 12            ...         10.6     /        ...  ...          ...
# 13            ...         14.8     /        ...  ...          ...
# 14            ...         15.8     /        ...  ...          ...
# 15            ...         15.6     /        ...  ...          ...
# 16            ...         13.0     /        ...  ...          ...
# 17            ...         16.7     /        ...  ...          ...
# 18            ...         10.9     /        ...  ...          ...
# 19            ...          8.8     /        ...  ...          ...
# 20            ...          8.1     /        ...  ...          ...
# 21            ...          7.9     /        ...  ...          ...
# 22            ...          8.8     /        ...  ...          ...
# 23            ...          6.7     /        ...  ...          ...
# 24            ...          7.8     /        ...  ...          ...
# 25            ...         13.0     /        ...  ...          ...
# 26            ...          9.9     /        ...  ...          ...
# 27            ...         10.0     /        ...  ...          ...
# 28            ...         13.7     /        ...  ...          ...
# 29            ...         14.5     /        ...  ...          ...
# 30            ...         16.6     /        ...  ...          ...
#
#    Cloud Amount stationid stationname city district  month  year yield_year  \
# 0           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 1           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 2           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 3           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 4           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 5           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 6           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 7           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 8           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 9           ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 10          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 11          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 12          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 13          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 14          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 15          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 16          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 17          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 18          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 19          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 20          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 21          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 22          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 23          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 24          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 25          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 26          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 27          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 28          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 29          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
# 30          ...    C0A920         富貴角  新北市      石門區     01  2004       2008
#
#                                   urlencoded_name
# 0   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 1   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 2   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 3   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 4   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 5   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 6   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 7   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 8   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 9   %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 10  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 11  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 12  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 13  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 14  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 15  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 16  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 17  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 18  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 19  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 20  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 21  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 22  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 23  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 24  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 25  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 26  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 27  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 28  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 29  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# 30  %25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
#
# [31 rows x 43 columns]

# %%
start_time = time.time()
overall_stationinfos = stationinfos+stationsinfos_mismatched
unique_stationinfos = pd.DataFrame(overall_stationinfos).drop(columns=['yield_year']).drop_duplicates().reset_index(drop=True).to_dict('records')
station_monthly_data = [dask.delayed(get_station_monthly_data_retrieve)(stationinfo) for stationinfo in unique_stationinfos[0:101]]
needscheduler = "threads" if True else "processes"
"""
for sinfo in unique_stationinfos:
    station_info_message = list(sinfo.values())
    sinfo['urlencoded_name'] = urllib.parse.quote(sinfo['stationname'], safe='~@#$&()*!+=:;,.?/\'', encoding='UTF-8').replace("%","%25")
    sinfo_weather_data_raw = "https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station={}&datepicker={}-{}&stname={}".format(sinfo['stationid'], sinfo['year'], sinfo['month'], sinfo['urlencoded_name'])
    try:
        t = "processing "+" ".join(station_info_message+[sinfo_weather_data_raw])
    except Exception as e:
        print(str(e))
        display(sinfo)
        break
"""
if True:
    with dask.config.set(num_workers=30, scheduler=needscheduler):  #204
        with ProgressBar():
            station_monthly_data_retrieved = dask.compute(*station_monthly_data)
    with dask.config.set(num_workers=600, scheduler=needscheduler):
        with ProgressBar():
            station_monthly_data = [dask.delayed(get_station_monthly_data_parse)(smd) for smd in station_monthly_data_retrieved]
            station_monthly_data = dask.compute(*station_monthly_data)
needtime = time.time() - start_time
print("--- %s seconds ---" % (needtime))
#110.41256833076477 12 workers processes
#110.30883741378784 12 workers threads
#35.71750545501709 60 workers processes
#26.521867990493774 60 workers threads
#300 jobs
#269.1925961971283 60 workers threads 600 workers threads
#104.53193426132202 80 workers threads 600 workers threads
#104.78928446769714 84 workers threads 600 workers threads
#103.09000277519226 96 workers threads 600 workers threads
#84.36256146430969 108 workers threads 600 workers threads
#83.18865132331848 120 workers threads 600 workers threads
#81.80956053733826 132 workers threads 600 workers threads
#65.56309628486633 156 workers threads 600 workers threads
#65.40118169784546 180 workers threads 600 workers threads
# Out:
# ery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-09&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 08 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-08&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 01 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 08 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-08&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I250 鯉潭 南投縣 埔里鎮 06 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-06&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C1I260 北坑 南投縣 埔里鎮 09 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-09&stname=%25E5%258C%2597%25E5%259D%2591
# processing C0A920 富貴角 新北市 石門區 10 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-10&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I250 鯉潭 南投縣 埔里鎮 01 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-01&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C1I250 鯉潭 南投縣 埔里鎮 02 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-02&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C1I240 外大坪 南投縣 埔里鎮 06 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-06&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C0A920 富貴角 新北市 石門區 04 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-04&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I260 北坑 南投縣 埔里鎮 02 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-02&stname=%25E5%258C%2597%25E5%259D%2591
# processing C0A920 富貴角 新北市 石門區 09 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-09&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 04 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-04&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# [                                        ] | 0% Completed |  0.1sprocessing C0A920 富貴角 新北市 石門區 02 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-02&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 05 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-05&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 08 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-08&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I250 鯉潭 南投縣 埔里鎮 05 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-05&stname=%25E9%25AF%2589%25E6%25BD%25ADprocessing C1I250 鯉潭 南投縣 埔里鎮 07 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-07&stname=%25E9%25AF%2589%25E6%25BD%25AD
#
# processing C0A920 富貴角 新北市 石門區 10 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-10&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 02 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-02&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 05 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-05&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# [                                        ] | 0% Completed |  0.2sprocessing C0A920 富貴角 新北市 石門區 09 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-09&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 03 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-03&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 06 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-06&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 07 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-07&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# [#                                       ] | 3% Completed |  0.3sprocessing C0A920 富貴角 新北市 石門區 06 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-06&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 01 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 01 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 11 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-11&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 02 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-02&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 06 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-06&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 01 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I260 北坑 南投縣 埔里鎮 04 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-04&stname=%25E5%258C%2597%25E5%259D%2591
# processing C0A920 富貴角 新北市 石門區 05 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-05&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 07 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-07&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 12 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-12&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# [#####                                   ] | 14% Completed |  0.5sprocessing C0A920 富貴角 新北市 石門區 07 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-07&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 08 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-08&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 07 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-07&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 12 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-12&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 03 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-03&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 07 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-07&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 08 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-08&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I250 鯉潭 南投縣 埔里鎮 04 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-04&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C1I240 外大坪 南投縣 埔里鎮 10 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-10&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C0A920 富貴角 新北市 石門區 07 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-07&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 04 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-04&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592processing C0A920 富貴角 新北市 石門區 04 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-04&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
#
# processing C0A920 富貴角 新北市 石門區 04 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-04&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I260 北坑 南投縣 埔里鎮 06 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-06&stname=%25E5%258C%2597%25E5%259D%2591
# processing C0A920 富貴角 新北市 石門區 02 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-02&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 09 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-09&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# [#############                           ] | 32% Completed |  0.6sprocessing C0A920 富貴角 新北市 石門區 02 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-02&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 09 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-09&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C0A920 富貴角 新北市 石門區 01 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 03 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-03&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C1I260 北坑 南投縣 埔里鎮 05 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-05&stname=%25E5%258C%2597%25E5%259D%2591
# processing C1I250 鯉潭 南投縣 埔里鎮 09 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-09&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C0A920 富貴角 新北市 石門區 12 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-12&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I260 北坑 南投縣 埔里鎮 07 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-07&stname=%25E5%258C%2597%25E5%259D%2591
# [###############                         ] | 38% Completed |  0.7sprocessing C0A920 富貴角 新北市 石門區 03 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-03&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 05 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-05&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 11 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-11&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 04 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-04&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 10 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-10&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 04 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-04&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C0A920 富貴角 新北市 石門區 10 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-10&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 11 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-11&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 02 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-02&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C0A920 富貴角 新北市 石門區 09 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-09&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 08 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-08&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# [####################                    ] | 50% Completed |  0.8sprocessing C1I250 鯉潭 南投縣 埔里鎮 08 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-08&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C0A920 富貴角 新北市 石門區 06 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-06&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 11 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-11&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 10 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-10&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I240 外大坪 南投縣 埔里鎮 01 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I240&datepicker=2003-01&stname=%25E5%25A4%2596%25E5%25A4%25A7%25E5%259D%25AA
# processing C0A920 富貴角 新北市 石門區 12 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-12&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I260 北坑 南投縣 埔里鎮 01 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-01&stname=%25E5%258C%2597%25E5%259D%2591
# processing C0A920 富貴角 新北市 石門區 01 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-01&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I260 北坑 南投縣 埔里鎮 08 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-08&stname=%25E5%258C%2597%25E5%259D%2591
# processing C0A920 富貴角 新北市 石門區 06 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-06&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 03 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-03&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C1I250 鯉潭 南投縣 埔里鎮 03 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-03&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C1I260 北坑 南投縣 埔里鎮 03 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I260&datepicker=2003-03&stname=%25E5%258C%2597%25E5%259D%2591
# [########################                ] | 62% Completed |  0.9sprocessing C1I250 鯉潭 南投縣 埔里鎮 10 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C1I250&datepicker=2003-10&stname=%25E9%25AF%2589%25E6%25BD%25AD
# processing C0A920 富貴角 新北市 石門區 07 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-07&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 08 2003 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2003-08&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 11 2007 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2007-11&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 03 2006 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2006-03&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 02 2004 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2004-02&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# processing C0A920 富貴角 新北市 石門區 12 2008 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2008-12&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# [###########################             ] | 69% Completed |  1.0sprocessing C0A920 富貴角 新北市 石門區 10 2005 https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=C0A920&datepicker=2005-10&stname=%25E5%25AF%258C%25E8%25B2%25B4%25E8%25A7%2592
# [########################################] | 100% Completed |  3.7s
# [########################################] | 100% Completed |  5.5s
# --- 9.782662868499756 seconds ---

# %%
yield_data_df.loc[failed_match_stations,['city','district','yield_year']]

# %%
station_monthly_data_col_definition = dict(zip(
    list(station_monthly_data[0]),
    "觀測時間(day)	測站氣壓(hPa)	海平面氣壓(hPa)	測站最高氣壓(hPa)	測站最高氣壓時間(LST)	測站最低氣壓(hPa)	測站最低氣壓時間(LST)	氣溫(℃)	最高氣溫(℃)	最高氣溫時間(LST)	最低氣溫(℃)	最低氣溫時間(LST)	露點溫度(℃)	相對溼度(%)	最小相對溼度(%)	最小相對溼度時間(LST)	風速(m/s)	風向(360degree)	最大陣風(m/s)	最大陣風風向(360degree)	最大陣風風速時間(LST)	降水量(mm)	降水時數(hour)	最大十分鐘降水量(mm)	最大十分鐘降水量起始時間(LST)	最大六十分鐘降水量(mm)	最大六十分鐘降水量起始時間(LST)	日照時數(hour)	日照率(%)	全天空日射量(MJ/㎡)	能見度(km)	A型蒸發量(mm)	日最高紫外線指數	日最高紫外線指數時間(LST)	總雲量(0~10)".split("	")
))
station_monthly_data_all_directly_matched = pd.concat(station_monthly_data).reset_index(drop=True)
#display(station_monthly_data_col_definition)
display(station_monthly_data_all_directly_matched.rename(columns=station_monthly_data_col_definition).head(n=5))
station_monthly_data_all.to_csv('station_monthly_data_all_directly_matched.csv')

# %%
model_input_x = list()
model_input_y = list()
for succeed_match_station in succeed_match_stations:
  t = pd.merge(
      left=pd.DataFrame(stationinfos).loc[[succeed_match_station],:],
      right=station_monthly_data_all,
      how='inner'
  )
  t = t.loc[:,['StnPres','Temperature','WS','WD','Precp','SunShine']].values.tolist()
  model_input_x.append(t)
  model_input_y.append(yield_data_df.loc[succeed_match_station,'每公頃收穫量(公斤)'])
#.values.tolist()

# %%
yield_data_df.index

# %%
for i,x in enumerate(model_input_x):
  print("I is "+str(i))
  print(model_input_y[i])
  #display(yield_data_df.iloc[model_input_y[i],:])
  print(x)
