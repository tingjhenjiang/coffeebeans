# %%
from tgc_goods_crawl import *
from IPython.display import display, HTML

# %% [markdown]
# # 蒐集資料及預處理資料

# %%
#注意 以下 有價錢
#'url': 'https://www.tgc-coffee.com/products/5cac603de52f1100269153d5',
#'title': '暢遊世界-精品滴濾式掛耳咖啡20入/盒',
#台灣華山二合一咖啡分享包 22入台灣華山二合一咖啡 沒價錢

tgc_website_goods_data_raw = get_tgc_website_goods_data_raw()
display(tgc_website_goods_data_raw)
# Out:
#                                    title category  \
# 0                           有你才幸福咖啡專屬防疫箱      伴手禮
# 1    TGC好評加碼防疫咖啡香 免運優惠四入組 讓一整天活力充沛  元氣滿滿      伴手禮
# 2                       腰健康豆防疫 黑豆腰果買3送1組      伴手禮
# 3          奇幻星座咖啡─橡木桶蜜釀掛耳式精品咖啡/一盒5入 買二送一      伴手禮
# 4           由內而外美麗奇肌美白精華液/綠原酸滴濾式咖啡一盒/20包      伴手禮
# ..                                   ...      ...
# 108                 【Tiamo】 陶瓷濾杯(小，1-2人)   咖啡周邊商品
# 109           【CAFFC】 V01圓錐咖啡濾紙1-2人 100入   咖啡周邊商品
# 110           【CAFFC】 V02圓錐咖啡濾紙1-4人 100入   咖啡周邊商品
# 111                         【Tiamo】電動磨豆機   咖啡周邊商品
# 112                          【楊家】飛馬牌600N   咖啡周邊商品
#
#                                                summary  \
# 0    現在訂，馬上到❗️『有你才幸福咖啡專屬防疫箱』六件組經典品項一次幫您搭配好 都是最新鮮現烘的...
# 1    綠原酸滴濾式咖啡20 入典藏意式特調滴濾式咖啡20 入原味奶茶分享袋20 入咖啡麥片分享袋1...
# 2
# 3    ✔️ 精選台灣最優質的生豆✔️ 橡木桶厭氧發酵✔️ 烘焙前、後人工手選剔除瑕疵豆✔️ 新鮮現...
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111
# 112
#
# ...

# %%
tgc_website_goods_data_raw_save = get_tgc_website_goods_data_wseg(tgc_website_goods_data_raw)
tgc_website_goods_data_raw_save.to_csv(destSaveCSVfile)
tgc_website_goods_data_raw_save[tgc_website_goods_data_raw_save['title'].str.contains('華山')]
# Out:
#                     title  category summary  \
# 86       台灣華山三合一咖啡分享包 22入  即溶沖泡華山系列
# 87       台灣華山二合一咖啡量販 100入  即溶沖泡華山系列
# 88  台灣華山二合一咖啡15入，特惠買八盒送一盒  即溶沖泡華山系列
# 89  台灣華山三合一咖啡15入，特惠買八盒送一盒  即溶沖泡華山系列
# 90       台灣華山二合一咖啡分享包 22入  即溶沖泡華山系列
# 91       台灣華山三合一咖啡量販 100入  即溶沖泡華山系列
#
#                                           description  price  \
# 86  產品介紹：使用特選即溶咖啡粉,並添加台灣本產製咖啡粉, 散發特殊風味,濃郁香純,自然回甘,原...  160.0
# 87  ※選用超商取貨、超商貨付服務得依符合材積90cm以下(兩組以上另收運費)產品介紹：使用特選即...  600.0
# 88  產品介紹：使用特選即溶咖啡粉,並添加台灣本產製咖啡粉, 散發特殊風味,濃郁香純,自然回甘,原...  150.0
# 89  產品介紹：使用特選即溶咖啡粉,並添加台灣本產製咖啡粉, 散發特殊風味,濃郁香純,自然回甘,原...  150.0
# 90  產品介紹：使用特選即溶咖啡粉,並添加台灣本產製咖啡粉, 散發特殊風味,濃郁香純,自然回甘,原...  160.0
# 91  ※選用超商取貨、超商貨付服務得依符合材積90cm以下(兩組以上另收運費)產品介紹：使用特選即...  600.0
#
#                                               alltext  \
# 86  台灣華山三合一咖啡分享包 22入\n\n產品介紹：使用特選即溶咖啡粉,並添加台灣本產製咖啡粉...
# 87  台灣華山二合一咖啡量販 100入\n\n※選用超商取貨、超商貨付服務得依符合材積90cm以下...
# 88  台灣華山二合一咖啡15入，特惠買八盒送一盒\n\n產品介紹：使用特選即溶咖啡粉,並添加台灣本...
# ...
